# %%
import sys, os
os.chdir('/Users/lananhnguyen/Desktop/thesis')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller
import pmdarima as pm

from sklearn.model_selection import train_test_split

from sklearn.metrics import (confusion_matrix, roc_curve, roc_auc_score, accuracy_score, precision_score,
                             recall_score, f1_score, classification_report, log_loss, make_scorer)
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA

# %%
headline_cpi = pd.read_excel('Headline_HICP_yoy.xlsx')
headline_cpi.head()
# Out:
#         date   s1  s2zz  s2
# 0 1997-01-31  1.9   NaN NaN
# 1 1997-02-28  1.6   1.0 NaN
# 2 1997-03-31  1.3   1.0 NaN
# 3 1997-04-30  1.2   1.0 NaN
# 4 1997-05-31  1.5   1.0 NaN

# %% [markdown]
# # 1. AR(p) model
#
# Since we have covid period and it can mess with our data, we'll do:
# split out-of-sampple forcasting into 3 periods: precovid, in covid and after covid.

# %%
headline_cpi.head(5)
# Out:
#         date   s1  s2zz  s2
# 0 1997-01-31  1.9   NaN NaN
# 1 1997-02-28  1.6   1.0 NaN
# 2 1997-03-31  1.3   1.0 NaN
# 3 1997-04-30  1.2   1.0 NaN
# 4 1997-05-31  1.5   1.0 NaN

# %%
headline_cpi.drop('s2zz', axis=1, inplace=True)
headline_cpi = headline_cpi.set_index('date')
headline_cpi = headline_cpi.asfreq('M')
headline_cpi.head()
# Out:
#              s1  s2
# date
# 1997-01-31  1.9 NaN
# 1997-02-28  1.6 NaN
# 1997-03-31  1.3 NaN
# 1997-04-30  1.2 NaN
# 1997-05-31  1.5 NaN

# %%
headline_yoy = headline_cpi['s2'].dropna(axis = 0)
headline_yoy
# Out:
# date
# 1998-01-31   -1.2
# 1998-02-28   -1.1
# 1998-03-31   -0.8
# 1998-04-30   -0.3
# 1998-05-31   -0.6
#              ...
# 2023-01-31    4.1
# 2023-02-28    3.8
# 2023-03-31    0.2
# 2023-04-30   -0.2
# 2023-05-31   -2.4
# Freq: M, Name: s2, Length: 305, dtype: float64

# %%
plt.figure(figsize = (12, 4))
plt.plot(headline_yoy)
plt.show()

# %%
autocorr = headline_yoy.autocorr()
print("Autocorrelation:", autocorr)
# Out:
# Autocorrelation: 0.9143928212857725

# %%
import statsmodels.tsa.stattools as ts
def dftest(timeseries):
    dftest = ts.adfuller(timeseries,) #call function adfuller 
    dfoutput = pd.Series(dftest[0:4],  
                         index=['Test Statistic','p-value','Lags Used','Observations Used'])
    # display first 4 values with its name
    
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput) #5th value is the CV
    
dftest(headline_yoy)
# Out:
# Test Statistic           -4.497171
# p-value                   0.000199
# Lags Used                14.000000
# Observations Used       290.000000
# Critical Value (1%)      -3.453102
# Critical Value (5%)      -2.871559
# Critical Value (10%)     -2.572108
# dtype: float64

# %% [markdown]
# It's stationary AR model.

# %%
# define helper plot function for visualization

def plots(data, lags=None):
    plt.figure(figsize=(15, 4))
    layout = (1, 3)
    raw  = plt.subplot2grid(layout, (0, 0))
    acf  = plt.subplot2grid(layout, (0, 1))
    pacf = plt.subplot2grid(layout, (0, 2))
    
    raw.plot(data)
    plot_acf(data, lags=lags, ax=acf, zero=False)
    plot_pacf(data, lags=lags, ax=pacf, zero = False)
    sns.despine()
    plt.tight_layout()
    
plots(headline_yoy, lags = 37)
# Out:
# /Users/lananhnguyen/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ACF is initially large, then decays gradually to zero, then switch to be negative.
# p = 1, 13, 25, 37,... have large PACF -> annual seasonality.
#
# Also I'll split the data so to have out-of-sample forecast, and there's covid time, so I will split like:
# training data: 1/1998-12/2015
# test 1: 1/2016 - 12/2019 - precovid
# test 2: 2020-2021 - during covid
# test 3: 2022 - after covid and ukrain war and energy spike

# %%
headline_train = headline_yoy[headline_yoy.index <= '2015-12-31']

# %%
headline_test = headline_yoy[headline_yoy.index > '2015-12-31']
headline_t1 = headline_yoy[(headline_yoy.index > '2015-12-31') & (headline_yoy.index <= '2019-12-31')]
headline_t2 = headline_yoy[(headline_yoy.index > '2019-12-31') & (headline_yoy.index <= '2021-12-31')]
headline_t3 = headline_yoy[headline_yoy.index > '2021-12-31']
print('Pre-covid observations: ', len(headline_t1))
print('During covid observations: ', len(headline_t2))
print('After covid:' , len(headline_t3))
# Out:
# Pre-covid observations:  48
# During covid observations:  24
# After covid: 17

# %%
#from pyramid.arima import auto_arima
stepwise_model = pm.auto_arima(headline_train, 
                            start_p=1, start_q=0,
                           max_p=12, max_q=0, m=12,
                           start_P=1, seasonal=True,
                           d=0, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True,
                            information_criterion='bic') 
print(stepwise_model.bic())
# Out:
# Performing stepwise search to minimize bic
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : BIC=inf, Time=0.85 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : BIC=816.891, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : BIC=469.626, Time=0.18 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : BIC=inf, Time=0.40 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : BIC=811.737, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : BIC=573.618, Time=0.03 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : BIC=381.109, Time=0.60 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : BIC=inf, Time=1.92 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : BIC=713.491, Time=0.27 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : BIC=381.626, Time=0.73 sec
#  ARIMA(1,0,0)(2,1,0)[12]             : BIC=375.808, Time=0.22 sec
#  ARIMA(1,0,0)(1,1,0)[12]             : BIC=464.395, Time=0.09 sec
#  ARIMA(1,0,0)(2,1,1)[12]             : BIC=inf, Time=1.62 sec
#  ARIMA(1,0,0)(1,1,1)[12]             : BIC=inf, Time=0.61 sec
#  ARIMA(0,0,0)(2,1,0)[12]             : BIC=708.287, Time=0.09 sec
#  ARIMA(2,0,0)(2,1,0)[12]             : BIC=376.344, Time=0.33 sec
#
# Best model:  ARIMA(1,0,0)(2,1,0)[12]
# Total fit time: 8.008 seconds
# 375.8079945746423

# %% [markdown]
# I tried with both AIC and BIC, same results.

# %%
order = stepwise_model.order
seasonal_order = stepwise_model.seasonal_order
print('order: ',order)
print('seasonal order: ',seasonal_order)
# Out:
# order:  (1, 0, 0)
# seasonal order:  (2, 1, 0, 12)

# %%
sar = SARIMAX(headline_train, 
                order=order,
                seasonal_order=seasonal_order,
                 trend ='n').fit()
sar.summary()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.04946D+00    |proj g|=  5.68868D-01
#
# At iterate    5    f=  8.29922D-01    |proj g|=  4.54265D-02
#
# At iterate   10    f=  8.20701D-01    |proj g|=  2.67178D-03
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     13     18      1     0     0   5.954D-05   8.207D-01
#   F =  0.82068406157237361
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                 s2   No. Observations:                  216
# Model:             SARIMAX(1, 0, 0)x(2, 1, 0, 12)   Log Likelihood                -177.268
# Date:                            Sat, 04 Nov 2023   AIC                            362.536
# Time:                                    17:42:58   BIC                            375.808
# Sample:                                01-31-1998   HQIC                           367.904
#                                      - 12-31-2015
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9200      0.026     35.350      0.000       0.869       0.971
# ar.S.L12      -1.0794      0.049    -22.245      0.000      -1.174      -0.984
# ar.S.L24      -0.6224      0.053    -11.642      0.000      -0.727      -0.518
# sigma2         0.3020      0.026     11.683      0.000       0.251       0.353
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.62   Jarque-Bera (JB):                10.39
# Prob(Q):                              0.06   Prob(JB):                         0.01
# Heteroskedasticity (H):               1.22   Skew:                            -0.39
# Prob(H) (two-sided):                  0.41   Kurtosis:                         3.78
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
#plot the residuals

plots(sar.resid[sar.loglikelihood_burn:], lags=36);
# Out:
# /Users/lananhnguyen/anaconda3/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# It makes sense that the residuals are not white noise and still autocorrelated, the reason is that the columns having missing values are dropped.
#
# Now let's do out-of-sample forecast and calculate RMSE.

# %%
T = len(headline_train)
N = len(headline_test)
horizons = [1, 2, 3] # horizon

# Create empty lists to store the forecasts
forecast_df = pd.DataFrame()

# Iterate through the time series data
for h in horizons:
    forecasts = []    
    for i in range(1, N+1):
    
        # Define the expanding window training set
        train_data = headline_yoy[:T+i-h]
        print(f'Horizon {h}, step {i}')

        # Create and fit the SARIMAX model
        model = SARIMAX(train_data, order=order, seasonal_order=seasonal_order, trend='n')
        model_fit = model.fit(disp = False)
    
        # Forecast h step ahead
        pred = model_fit.forecast(steps =h)
        print('Prediction: ', pred)
        forecasts.append(pred[-1])
    # Assign the forecasted values to a new column in the DataFrame
    forecast_df[f'Horizon_{h}'] = forecasts
forecast_df['Real_obs'] = headline_test.values
forecast_df.set_index(headline_test.index, inplace = True)
# Out:
# Horizon 1, step 1
# prediction 2016-01-31   -0.102466
# Freq: M, dtype: float64
# Horizon 1, step 2
# prediction 2016-02-29    0.566975
# Freq: M, dtype: float64
# Horizon 1, step 3
# prediction 2016-03-31    0.028438
# Freq: M, dtype: float64
# Horizon 1, step 4
# prediction 2016-04-30   -0.153772
# Freq: M, dtype: float64
# Horizon 1, step 5
# prediction 2016-05-31   -1.382254
# Freq: M, dtype: float64
# Horizon 1, step 6
# prediction 2016-06-30   -1.256929
# Freq: M, dtype: float64
# Horizon 1, step 7
# prediction 2016-07-31   -1.083964
# Freq: M, dtype: float64
# Horizon 1, step 8
# prediction 2016-08-31   -1.239831
# Freq: M, dtype: float64
# Horizon 1, step 9
# prediction 2016-09-30   -0.713245
# Freq: M, dtype: float64
# Horizon 1, step 10
# prediction 2016-10-31   -0.329355
# Freq: M, dtype: float64
# Horizon 1, step 11
# prediction 2016-11-30   -0.344473
# Freq: M, dtype: float64
# Horizon 1, step 12
# prediction 2016-12-31    0.068424
# Freq: M, dtype: float64
# Horizon 1, step 13
# prediction 2017-01-31    0.969004
# Freq: M, dtype: float64
# Horizon 1, step 14
# prediction 2017-02-28    1.355842
# Freq: M, dtype: float64
# Horizon 1, step 15
# prediction 2017-03-31    2.112021
# Freq: M, dtype: float64
# Horizon 1, step 16
# prediction 2017-04-30    2.233231
# Freq: M, dtype: float64
# Horizon 1, step 17
# prediction 2017-05-31    2.111027
# Freq: M, dtype: float64
# Horizon 1, step 18
# prediction 2017-06-30    0.721852
# Freq: M, dtype: float64
# Horizon 1, step 19
# prediction 2017-07-31    1.484711
# Freq: M, dtype: float64
# Horizon 1, step 20
# prediction 2017-08-31    1.490676
# Freq: M, dtype: float64
# Horizon 1, step 21
# prediction 2017-09-30    1.274341
# Freq: M, dtype: float64
# Horizon 1, step 22
# prediction 2017-10-31    1.542637
# Freq: M, dtype: float64
# Horizon 1, step 23
# prediction 2017-11-30   -0.09402
# Freq: M, dtype: float64
# Horizon 1, step 24
# prediction 2017-12-31    0.880675
# Freq: M, dtype: float64
# Horizon 1, step 25
# prediction 2018-01-31   -0.120026
# Freq: M, dtype: float64
# Horizon 1, step 26
# prediction 2018-02-28   -0.397794
# Freq: M, dtype: float64
# Horizon 1, step 27
# prediction 2018-03-31   -0.457779
# Freq: M, dtype: float64
# Horizon 1, step 28
# prediction 2018-04-30   -0.212017
# Freq: M, dtype: float64
# Horizon 1, step 29
# prediction 2018-05-31   -0.164308
# Freq: M, dtype: float64
# Horizon 1, step 30
# prediction 2018-06-30    0.902281
# Freq: M, dtype: float64
# Horizon 1, step 31
# prediction 2018-07-31    0.614314
# Freq: M, dtype: float64
# Horizon 1, step 32
# prediction 2018-08-31    0.311812
# Freq: M, dtype: float64
# Horizon 1, step 33
# prediction 2018-09-30    0.248284
# Freq: M, dtype: float64
# Horizon 1, step 34
# prediction 2018-10-31    0.509112
# Freq: M, dtype: float64
# Horizon 1, step 35
# prediction 2018-11-30    0.94334
# Freq: M, dtype: float64
# Horizon 1, step 36
# prediction 2018-12-31    1.170718
# Freq: M, dtype: float64
# Horizon 1, step 37
# prediction 2019-01-31    0.740589
# Freq: M, dtype: float64
# Horizon 1, step 38
# prediction 2019-02-28    0.194435
# Freq: M, dtype: float64
# Horizon 1, step 39
# prediction 2019-03-31   -0.088947
# Freq: M, dtype: float64
# Horizon 1, step 40
# prediction 2019-04-30   -0.49873
# Freq: M, dtype: float64
# Horizon 1, step 41
# prediction 2019-05-31   -0.092154
# Freq: M, dtype: float64
# Horizon 1, step 42
# prediction 2019-06-30   -0.503763
# Freq: M, dtype: float64
# Horizon 1, step 43
# prediction 2019-07-31   -0.648783
# Freq: M, dtype: float64
# Horizon 1, step 44
# prediction 2019-08-31   -0.755917
# Freq: M, dtype: float64
# Horizon 1, step 45
# prediction 2019-09-30   -0.739514
# Freq: M, dtype: float64
# Horizon 1, step 46
# prediction 2019-10-31   -1.672537
# Freq: M, dtype: float64
# Horizon 1, step 47
# prediction 2019-11-30   -0.721738
# Freq: M, dtype: float64
# Horizon 1, step 48
# prediction 2019-12-31   -0.743384
# Freq: M, dtype: float64
# Horizon 1, step 49
# prediction 2020-01-31   -0.221295
# Freq: M, dtype: float64
# Horizon 1, step 50
# prediction 2020-02-29    0.224983
# Freq: M, dtype: float64
# Horizon 1, step 51
# prediction 2020-03-31    0.137843
# Freq: M, dtype: float64
# Horizon 1, step 52
# prediction 2020-04-30    0.069764
# Freq: M, dtype: float64
# Horizon 1, step 53
# prediction 2020-05-31   -0.585213
# Freq: M, dtype: float64
# Horizon 1, step 54
# prediction 2020-06-30   -0.912822
# Freq: M, dtype: float64
# Horizon 1, step 55
# prediction 2020-07-31   -0.566074
# Freq: M, dtype: float64
# Horizon 1, step 56
# prediction 2020-08-31   -0.917564
# Freq: M, dtype: float64
# Horizon 1, step 57
# prediction 2020-09-30   -1.044896
# Freq: M, dtype: float64
# Horizon 1, step 58
# prediction 2020-10-31   -1.032591
# Freq: M, dtype: float64
# Horizon 1, step 59
# prediction 2020-11-30   -1.490357
# Freq: M, dtype: float64
# Horizon 1, step 60
# prediction 2020-12-31   -2.587816
# Freq: M, dtype: float64
# Horizon 1, step 61
# prediction 2021-01-31   -2.108929
# Freq: M, dtype: float64
# Horizon 1, step 62
# prediction 2021-02-28   -0.333744
# Freq: M, dtype: float64
# Horizon 1, step 63
# prediction 2021-03-31    0.241521
# Freq: M, dtype: float64
# Horizon 1, step 64
# prediction 2021-04-30    0.679346
# Freq: M, dtype: float64
# Horizon 1, step 65
# prediction 2021-05-31    1.46632
# Freq: M, dtype: float64
# Horizon 1, step 66
# prediction 2021-06-30    1.504721
# Freq: M, dtype: float64
# Horizon 1, step 67
# prediction 2021-07-31    1.084373
# Freq: M, dtype: float64
# Horizon 1, step 68
# prediction 2021-08-31    2.656713
# Freq: M, dtype: float64
# Horizon 1, step 69
# prediction 2021-09-30    3.227944
# Freq: M, dtype: float64
# Horizon 1, step 70
# prediction 2021-10-31    4.562374
# Freq: M, dtype: float64
# Horizon 1, step 71
# prediction 2021-11-30    4.773617
# Freq: M, dtype: float64
# Horizon 1, step 72
# prediction 2021-12-31    6.606785
# Freq: M, dtype: float64
# Horizon 1, step 73
# prediction 2022-01-31    5.875197
# Freq: M, dtype: float64
# Horizon 1, step 74
# prediction 2022-02-28    3.541737
# Freq: M, dtype: float64
# Horizon 1, step 75
# prediction 2022-03-31    2.956092
# Freq: M, dtype: float64
# Horizon 1, step 76
# prediction 2022-04-30    5.374222
# Freq: M, dtype: float64
# Horizon 1, step 77
# prediction 2022-05-31    4.221865
# Freq: M, dtype: float64
# Horizon 1, step 78
# prediction 2022-06-30    6.509703
# Freq: M, dtype: float64
# Horizon 1, step 79
# prediction 2022-07-31    5.109782
# Freq: M, dtype: float64
# Horizon 1, step 80
# prediction 2022-08-31    5.08539
# Freq: M, dtype: float64
# Horizon 1, step 81
# prediction 2022-09-30    4.812962
# Freq: M, dtype: float64
# Horizon 1, step 82
# prediction 2022-10-31    6.220045
# Freq: M, dtype: float64
# Horizon 1, step 83
# prediction 2022-11-30    6.855582
# Freq: M, dtype: float64
# Horizon 1, step 84
# prediction 2022-12-31    5.45153
# Freq: M, dtype: float64
# Horizon 1, step 85
# prediction 2023-01-31    5.054213
# Freq: M, dtype: float64
# Horizon 1, step 86
# prediction 2023-02-28    3.88523
# Freq: M, dtype: float64
# Horizon 1, step 87
# prediction 2023-03-31    3.802731
# Freq: M, dtype: float64
# Horizon 1, step 88
# prediction 2023-04-30   -0.306829
# Freq: M, dtype: float64
# Horizon 1, step 89
# prediction 2023-05-31    0.307103
# Freq: M, dtype: float64
# Horizon 2, step 1
# prediction 2015-12-31   -0.160946
# 2016-01-31   -0.342116
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 2
# prediction 2016-01-31   -0.102466
# 2016-02-29   -0.356708
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 3
# prediction 2016-02-29    0.566975
# 2016-03-31    0.460768
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 4
# prediction 2016-03-31    0.028438
# 2016-04-30    0.055619
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 5
# prediction 2016-04-30   -0.153772
# 2016-05-31   -0.339390
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 6
# prediction 2016-05-31   -1.382254
# 2016-06-30   -0.965841
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 7
# prediction 2016-06-30   -1.256929
# 2016-07-31   -1.319484
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 8
# prediction 2016-07-31   -1.083964
# 2016-08-31   -1.316641
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 9
# prediction 2016-08-31   -1.239831
# 2016-09-30   -1.116645
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 10
# prediction 2016-09-30   -0.713245
# 2016-10-31   -0.799508
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 11
# prediction 2016-10-31   -0.329355
# 2016-11-30   -0.189317
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 12
# prediction 2016-11-30   -0.344473
# 2016-12-31   -0.791737
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step 13
# prediction 2016-12-31    0.068424
# 2017-01-31   -0.270539
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 2, step
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 74
# prediction 2021-12-31    6.606785
# 2022-01-31    6.082875
# 2022-02-28    6.069417
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 75
# prediction 2022-01-31    5.875197
# 2022-02-28    5.860186
# 2022-03-31    4.914775
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 76
# prediction 2022-02-28    3.541737
# 2022-03-31    2.617164
# 2022-04-30    2.519333
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 77
# prediction 2022-03-31    2.956092
# 2022-04-30    2.841764
# 2022-05-31    1.416902
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 78
# prediction 2022-04-30    5.374222
# 2022-05-31    3.904803
# 2022-06-30    4.146038
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 79
# prediction 2022-05-31    4.221865
# 2022-06-30    4.460583
# 2022-07-31    3.433822
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 80
# prediction 2022-06-30    6.509703
# 2022-07-31    5.521098
# 2022-08-31    5.209394
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 81
# prediction 2022-07-31    5.109782
# 2022-08-31    4.792409
# 2022-09-30    4.198406
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 82
# prediction 2022-08-31    5.085390
# 2022-09-30    4.496036
# 2022-10-31    3.880308
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 83
# prediction 2022-09-30    4.812962
# 2022-10-31    4.198873
# 2022-11-30    3.994563
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 84
# prediction 2022-10-31    6.220045
# 2022-11-30    6.050721
# 2022-12-31    6.224155
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 85
# prediction 2022-11-30    6.855582
# 2022-12-31    7.047999
# 2023-01-31    8.224024
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 86
# prediction 2022-12-31    5.451530
# 2023-01-31    6.629534
# 2023-02-28    6.385963
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 87
# prediction 2023-01-31    5.054213
# 2023-02-28    4.812878
# 2023-03-31    4.772160
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 88
# prediction 2023-02-28    3.885230
# 2023-03-31    3.885706
# 2023-04-30    3.252154
# Freq: M, Name: predicted_mean, dtype: float64
# Horizon 3, step 89
# prediction 2023-03-31    3.802731
# 2023-04-30    3.171565
# 2023-05-31    3.540046
# Freq: M, Name: predicted_mean, dtype: float64

# %%
for h in horizons:
    forecast_df[f'Error_horizon_{h}'] = forecast_df['Real_obs'] - forecast_df[f'Horizon_{h}']
forecast_df.head()
# Out:
#             Horizon_1  Horizon_2  Horizon_3  Real_obs  Error_horizon1  \
# date
# 2016-01-31  -0.102466  -0.342116   0.488911       0.9        1.002466
# 2016-02-29   0.566975  -0.356708  -0.576232       0.1       -0.466975
# 2016-03-31   0.028438   0.460768  -0.386975      -0.2       -0.228438
# 2016-04-30  -0.153772   0.055619   0.457336      -1.3       -1.146228
# 2016-05-31  -1.382254  -0.339390  -0.144027      -1.7       -0.317746
#
#             Error_horizon2  Error_horizon3  Error_horizon_1  Error_horizon_2  \
# date
# 2016-01-31        1.242116        0.411089         1.002466         1.242116
# 2016-02-29        0.456708        0.676232        -0.466975         0.456708
# 2016-03-31       -0.660768        0.186975        -0.228438        -0.660768
# 2016-04-30       -1.355619       -1.757336        -1.146228        -1.355619
# 2016-05-31       -1.360610       -1.555973        -0.317746        -1.360610
#
#             Error_horizon_3
# date
# 2016-01-31         0.411089
# 2016-02-29         0.676232
# 2016-03-31         0.186975
# 2016-04-30        -1.757336
# 2016-05-31        -1.555973

# %%
plt.figure(figsize = (12, 8))
plt.subplot(211)
plt.plot(forecast_df['Horizon_1'], label = 'Forecasts horizon 1')
plt.plot(forecast_df['Real_obs'], label = 'Real observations')
plt.legend()
plt.subplot(212)
plt.plot(forecast_df['Error_horizon_1'], label = 'Error')
plt.axhline(y = 0, color = 'red', linestyle = '--')
plt.legend()
plt.show()

# %%
# Cut it out into three different periods:

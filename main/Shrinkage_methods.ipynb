# %%
from os import chdir
chdir('/Users/lananhnguyen/Desktop/thesis/thesis_code')
from packages.load import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge, Lasso
from sklearn.pipeline import Pipeline

# %% [markdown]
# # 3. Shrinkage method:

# %%
HICP_monthly = pd.read_csv('data/preprocessed/hicp_yoy.csv')
HICP_monthly['date'] = pd.to_datetime(HICP_monthly['date'])
HICP_monthly.set_index('date', inplace=True)

# %%
HICP_Weights = pd.read_excel('data/HICP_COICOP10s.xlsx', sheet_name='HICP_Weights')
HICP_Weights.head()
# Out:
#       mdates  Rice  Rice.preparations  Flour  Semolina..rye.flour.or.the.like  \
# 0 1996-01-31  0.41                NaN   0.35                             0.22
# 1 1996-02-29  0.41                NaN   0.35                             0.22
# 2 1996-03-31  0.41                NaN   0.35                             0.22
# 3 1996-04-30  0.41                NaN   0.35                             0.22
# 4 1996-05-31  0.41                NaN   0.35                             0.22
#
#    White.bread  Rye.bread.or.brown.bread  Granary.bread.or.wholemeal.bread  \
# 0         0.68                      2.25                              1.27
# 1         0.68                      2.25                              1.27
# 2         0.68                      2.25                              1.27
# 3         0.68                      2.25                              1.27
# 4         0.68                      2.25                              1.27
#
#    Ready.to.bake.rolls  Fresh.bread.rolls  ...  \
# 0                  NaN                4.0  ...
# 1                  NaN                4.0  ...
# 2                  NaN                4.0  ...
# 3                  NaN                4.0  ...
# 4                  NaN                4.0  ...
#
#    Premium.for.personal.liability.insurance  \
# 0                                      4.37
# 1                                      4.37
# 2                                      4.37
# 3                                      4.37
# 4                                      4.37
#
#    Premium.for.legal.protection.insurance  Bank.charges  \
# 0                                     1.8          3.15
# 1                                     1.8          3.15
# 2                                     1.8          3.15
# 3                                     1.8          3.15
# 4                                     1.8          3.15
#
#    Charge.for.tax.consultant.services  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Charge.for.birth.certificate..death.certificate.or.the.like  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Passport.fee.or.the.like  Fee.for.lawyer.s.or.notary.s.services  \
# 0                       1.1                                   1.04
# 1                       1.1                                   1.04
# 2                       1.1                                   1.04
# 3                       1.1                                   1.04
# 4                       1.1                                   1.04
#
#    Charge.for.funeral.services.or.cemetery.fee  \
# 0                                         0.51
# 1                                         0.51
# 2                                         0.51
# 3                                         0.51
# 4                                         0.51
#
#    Classified.advertisement.in.a.newspaper  Visitor.s.tax
# 0                                     0.44            NaN
# 1                                     0.44            NaN
# 2                                     0.44            NaN
# 3                                     0.44            NaN
# 4                                     0.44            NaN
#
# [5 rows x 645 columns]

# %%
HICP_class = pd.read_excel('data/HICP_COICOP10s.xlsx', sheet_name='COICOP_class')
HICP_class.index = ['Group 1', 'Group 2', 'Group 3', 'Group 4']
HICP_class.head()
# Out:
#                       Rice  Rice.preparations              Flour  \
# Group 1               Food               Food               Food
# Group 2     Processed food     Processed food     Processed food
# Group 3  bread and cereals  bread and cereals  bread and cereals
# Group 4  bread and cereals  bread and cereals  bread and cereals
#
#         Semolina..rye.flour.or.the.like        White.bread  \
# Group 1                            Food               Food
# Group 2                  Processed food     Processed food
# Group 3               bread and cereals  bread and cereals
# Group 4               bread and cereals  bread and cereals
#
#         Rye.bread.or.brown.bread Granary.bread.or.wholemeal.bread  \
# Group 1                     Food                             Food
# Group 2           Processed food                   Processed food
# Group 3        bread and cereals                bread and cereals
# Group 4        bread and cereals                bread and cereals
#
#         Ready.to.bake.rolls  Fresh.bread.rolls       Yeast.pastry  ...  \
# Group 1                Food               Food               Food  ...
# Group 2      Processed food     Processed food     Processed food  ...
# Group 3   bread and cereals  bread and cereals  bread and cereals  ...
# Group 4   bread and cereals  bread and cereals  bread and cereals  ...
#
#         Premium.for.personal.liability.insurance  \
# Group 1                                 Non-food
# Group 2                                 Services
# Group 3                   miscellaneous services
# Group 4                   miscellaneous services
#
#         Premium.for.legal.protection.insurance            Bank.charges  \
# Group 1                               Non-food                Non-food
# Group 2                               Services                Services
# Group 3                 miscellaneous services  miscellaneous services
# Group 4                 miscellaneous services  miscellaneous services
#
#         Charge.for.tax.consultant.services  \
# Group 1                           Non-food
# Group 2                           Services
# Group 3             miscellaneous services
# Group 4             miscellaneous services
#
#         Charge.for.birth.certificate..death.certificate.or.the.like  \
# Group 1                                           Non-food
# Group 2                                           Services
# Group 3                             miscellaneous services
# Group 4                             miscellaneous services
#
#         Passport.fee.or.the.like Fee.for.lawyer.s.or.notary.s.services  \
# Group 1                 Non-food                              Non-food
# Group 2                 Services                              Services
# Group 3   miscellaneous services                miscellaneous services
# Group 4   miscellaneous services                miscellaneous services
#
#         Charge.for.funeral.services.or.cemetery.fee  \
# Group 1                                    Non-food
# Group 2                                    Services
# Group 3                      miscellaneous services
# Group 4                      miscellaneous services
#
#         Classified.advertisement.in.a.newspaper           Visitor.s.tax
# Group 1                                Non-food                Non-food
# Group 2                                Services                Services
# Group 3                  miscellaneous services  miscellaneous services
# Group 4                  miscellaneous services  miscellaneous services
#
# [4 rows x 644 columns]

# %% [markdown]
# ## categories here is for food and alcohol:

# %%
# HICP for categories:

HICP_food = pd.read_csv('data/preprocessed/food_yoy_infl.csv')
HICP_food['date'] = pd.to_datetime(HICP_food['date'])
HICP_food.set_index('date', inplace=True)
HICP_food.head()
# Out:
#             yoy_rate
# date
# 1997-01-01  1.430615
# 1997-02-01  0.995733
# 1997-03-01  0.283286
# 1997-04-01  0.423729
# 1997-05-01  1.272984

# %%
HICP_monthly.tail(5)
# Out:
#                  Rice  Rice.preparations      Flour  \
# date
# 2022-08-31  20.160570          14.652015  39.402166
# 2022-09-30  19.383260          16.184450  39.872845
# 2022-10-31  23.309612          17.442928  37.840289
# 2022-11-30  24.110319          20.435975  63.300274
# 2022-12-31  25.156676          21.962198  58.111585
#
#             Semolina..rye.flour.or.the.like  White.bread  \
# date
# 2022-08-31                        28.884825    12.735423
# 2022-09-30                        28.153560    13.879002
# 2022-10-31                        29.055917    15.555556
# 2022-11-30                        29.927666    15.330391
# 2022-12-31                        16.172942    15.992967
#
#             Rye.bread.or.brown.bread  Granary.bread.or.wholemeal.bread  \
# date
# 2022-08-31                 14.559719                         15.075827
# 2022-09-30                 17.130432                         13.553431
# 2022-10-31                 17.478266                         15.077991
# 2022-11-30                 19.393934                         19.810515
# 2022-12-31                 19.432494                         20.188193
#
#             Ready.to.bake.rolls  Fresh.bread.rolls  Yeast.pastry  ...  \
# date                                                              ...
# 2022-08-31            22.796073          19.982245     12.357580  ...
# 2022-09-30            23.813793          19.930066     13.350782  ...
# 2022-10-31            25.823686          21.153850     14.821273  ...
# 2022-11-30            27.876106          21.527781     14.818023  ...
# 2022-12-31            29.416965          20.754721     15.404483  ...
#
#             Premium.for.personal.liability.insurance  \
# date
# 2022-08-31                                 -1.061571
# 2022-09-30                                 -1.061571
# 2022-10-31                                 -1.061571
# 2022-11-30                                 -2.866239
# 2022-12-31                                 -2.866239
#
#             Premium.for.legal.protection.insurance  Bank.charges  \
# date
# 2022-08-31                                4.351209      5.107323
# 2022-09-30                                4.351209      5.107323
# 2022-10-31                                3.387228      4.017531
# 2022-11-30                                3.926102      3.714487
# 2022-12-31                                3.926102      3.413215
#
#             Charge.for.tax.consultant.services  \
# date
# 2022-08-31                            1.110165
# 2022-09-30                            1.110165
# 2022-10-31                            1.110165
# 2022-11-30                            1.110165
# 2022-12-31                            1.110165
#
#             Charge.for.birth.certificate..death.certificate.or.the.like  \
# date
# 2022-08-31                                           5.682864
# 2022-09-30                                           5.682864
# 2022-10-31                                           6.874427
# 2022-11-30                                           6.874427
# 2022-12-31                                           6.386861
#
#             Passport.fee.or.the.like  Fee.for.lawyer.s.or.notary.s.services  \
# date
# 2022-08-31                       0.0                               1.493846
# 2022-09-30                       0.0                               1.493846
# 2022-10-31                       0.0                               1.493846
# 2022-11-30                       0.0                               1.493846
# 2022-12-31                       0.0                               1.493846
#
#             Charge.for.funeral.services.or.cemetery.fee  \
# date
# 2022-08-31                                     4.757711
# 2022-09-30                                     4.845815
# 2022-10-31                                     4.741002
# 2022-11-30                                     4.732692
# 2022-12-31                                     4.820333
#
#             Classified.advertisement.in.a.newspaper  Visitor.s.tax
# date
# 2022-08-31                                 3.962100      -0.081438
# 2022-09-30                                 4.299226      -0.082575
# 2022-10-31                                 4.366437      -0.086579
# 2022-11-30                                 4.092068      -0.100501
# 2022-12-31                                 4.421773       0.297320
#
# [5 rows x 644 columns]

# %%
# Extract data into groups:
# Full data groups: 

food_col = HICP_class.loc[:, HICP_class.iloc[0, :] == 'Food'].columns
print('Number of items in food group: ', len(food_col))

food_df = HICP_monthly[food_col]
food_df.fillna(0, inplace=True)


# Divide into train and test set:

X_food_train, X_food_test = food_df[food_df.index <= '2015-12-31'].iloc[:-1, :], food_df[food_df.index > '2015-11-30'].iloc[:-1, :]
y_food_train, y_food_test = HICP_food[HICP_food.index <= '2015-12-31'][1:], HICP_food[HICP_food.index > '2015-12-31']

print(f'Training predictor period: {X_food_train.index[0]} to {X_food_train.index[-1]}')
print(f'Training dependent variable period: {y_food_train.index[0]} to {y_food_train.index[-1]}')
print(f'Test predictor period: {X_food_test.index[0]} to {X_food_test.index[-1]}')
print(f'Test dependent variable period: {y_food_test.index[0]} to {y_food_test.index[-1]}')
# Out:
# Number of items in food group:  180
# Training predictor period: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training dependent variable period: 1997-02-01 00:00:00 to 2015-12-01 00:00:00
# Test predictor period: 2015-12-31 00:00:00 to 2022-11-30 00:00:00
# Test dependent variable period: 2016-01-01 00:00:00 to 2023-07-01 00:00:00
# /var/folders/74/zq2msw1x2fj9j2zyq8njktnc0000gn/T/ipykernel_4010/964387530.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   food_df.fillna(0, inplace=True)

# %%
# 5-fold for train data + 1 horizon:
from shutil import rmtree

from joblib import Memory

# Create a temporary folder to store the transformers of the pipeline
location = "cachedir"
memory = Memory(location=location, verbose=10)

tscv = TimeSeriesSplit(n_splits=5, test_size=6)

pipe_r = Pipeline(
    [
        ("scaling", StandardScaler()),
        ("regression", Ridge()),
    ])

param_grid = {
    'regression__alpha': np.arange(0.9, 1.0, 0.001)
}

grid = GridSearchCV(pipe_r, n_jobs=1, param_grid=param_grid, cv = tscv)
grid.fit(X_food_train, y_food_train)
mean_scores = np.array(grid.cv_results_["mean_test_score"])

# %%
print(grid.best_params_)
# Out:
# {'regression__alpha': 0.9990000000000001}

# %%
horizons = [1, 2, 3]
max_horizon = 3

forecast_df = pd.DataFrame()

for i in range(1, len(X_food_test) + max_horizon + 1):

    # test data = 3 next observations

    X_train = food_df.iloc[:len(X_food_train) - max_horizon + i +1, :]
    y_train = HICP_food[1:len(X_food_train) - max_horizon + i + 2]
    # y_train is infl of t+1 

    X_test = food_df.iloc[len(X_food_train) - max_horizon +1+ i: len(X_food_train) + 1+ i]

    print(f'Predictor training period: {X_train.index[0]} to {X_train.index[-1]}')

    print(f'Forecast target period: {y_train.index[0]} to {y_train.index[-1]}')
    print(f'Predictor test period: {X_test.index}')

    #model = Ridge(alpha=1)
    #model.fit(train_data, test_data)
    #model.predict()
# Out:
# Predictor training period: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2015-11-01 00:00:00
# Predictor test period: DatetimeIndex(['2015-11-30', '2015-12-31', '2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2015-12-01 00:00:00
# Predictor test period: DatetimeIndex(['2015-12-31', '2016-01-31', '2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2015-12-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-01-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-01-31', '2016-02-29', '2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-01-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-02-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-02-29', '2016-03-31', '2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-02-29 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-03-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-03-31', '2016-04-30', '2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-03-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-04-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-04-30', '2016-05-31', '2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-04-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-05-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-05-31', '2016-06-30', '2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-05-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-06-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-06-30', '2016-07-31', '2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-06-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-07-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-07-31', '2016-08-31', '2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-07-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-08-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-08-31', '2016-09-30', '2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-08-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-09-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-09-30', '2016-10-31', '2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-09-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-10-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-10-31', '2016-11-30', '2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-10-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-11-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-11-30', '2016-12-31', '2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-11-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2016-12-01 00:00:00
# Predictor test period: DatetimeIndex(['2016-12-31', '2017-01-31', '2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2016-12-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-01-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-01-31', '2017-02-28', '2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-01-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-02-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-02-28', '2017-03-31', '2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-02-28 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-03-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-03-31', '2017-04-30', '2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-03-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-04-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-04-30', '2017-05-31', '2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-04-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-05-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-05-31', '2017-06-30', '2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-05-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-06-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-06-30', '2017-07-31', '2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-06-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-07-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-07-31', '2017-08-31', '2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-07-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-08-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-08-31', '2017-09-30', '2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-08-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-09-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-09-30', '2017-10-31', '2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-09-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-10-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-10-31', '2017-11-30', '2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-10-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-11-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-11-30', '2017-12-31', '2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-11-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2017-12-01 00:00:00
# Predictor test period: DatetimeIndex(['2017-12-31', '2018-01-31', '2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2017-12-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-01-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-01-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-02-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-02-28', '2018-03-31', '2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-02-28 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-03-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-03-31', '2018-04-30', '2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-03-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-04-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-04-30', '2018-05-31', '2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-04-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-05-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-05-31', '2018-06-30', '2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-05-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-06-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-06-30', '2018-07-31', '2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-06-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-07-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-07-31', '2018-08-31', '2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-07-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-08-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-08-31', '2018-09-30', '2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-08-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-09-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-09-30', '2018-10-31', '2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-09-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-10-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-10-31', '2018-11-30', '2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-10-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-11-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-11-30', '2018-12-31', '2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-11-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2018-12-01 00:00:00
# Predictor test period: DatetimeIndex(['2018-12-31', '2019-01-31', '2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2018-12-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-01-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-01-31', '2019-02-28', '2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-01-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-02-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-02-28', '2019-03-31', '2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-02-28 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-03-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-03-31', '2019-04-30', '2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-03-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-04-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-04-30', '2019-05-31', '2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-04-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-05-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-05-31', '2019-06-30', '2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-05-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-06-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-06-30', '2019-07-31', '2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-06-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-07-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-07-31', '2019-08-31', '2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-07-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-08-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-08-31', '2019-09-30', '2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-08-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-09-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-09-30', '2019-10-31', '2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-09-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-10-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-10-31', '2019-11-30', '2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-10-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-11-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-11-30', '2019-12-31', '2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-11-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2019-12-01 00:00:00
# Predictor test period: DatetimeIndex(['2019-12-31', '2020-01-31', '2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2019-12-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-01-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-01-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-02-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-02-29', '2020-03-31', '2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-02-29 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-03-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-03-31', '2020-04-30', '2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-03-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-04-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-04-30', '2020-05-31', '2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-04-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-05-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-05-31', '2020-06-30', '2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-05-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-06-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-06-30', '2020-07-31', '2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-06-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-07-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-07-31', '2020-08-31', '2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-07-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-08-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-08-31', '2020-09-30', '2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-08-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-09-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-09-30', '2020-10-31', '2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-09-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-10-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-10-31', '2020-11-30', '2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-10-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-11-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-11-30', '2020-12-31', '2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-11-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2020-12-01 00:00:00
# Predictor test period: DatetimeIndex(['2020-12-31', '2021-01-31', '2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2020-12-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-01-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-01-31', '2021-02-28', '2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-01-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-02-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-02-28', '2021-03-31', '2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-02-28 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-03-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-03-31', '2021-04-30', '2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-03-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-04-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-04-30', '2021-05-31', '2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-04-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-05-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-05-31', '2021-06-30', '2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-05-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-06-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-06-30', '2021-07-31', '2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-06-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-07-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-07-31', '2021-08-31', '2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-07-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-08-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-08-31', '2021-09-30', '2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-08-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-09-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-09-30', '2021-10-31', '2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-09-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-10-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-10-31', '2021-11-30', '2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-10-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-11-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-11-30', '2021-12-31', '2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-11-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2021-12-01 00:00:00
# Predictor test period: DatetimeIndex(['2021-12-31', '2022-01-31', '2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2021-12-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-01-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-01-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-02-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-02-28', '2022-03-31', '2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-02-28 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-03-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-03-31', '2022-04-30', '2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-03-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-04-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-04-30', '2022-05-31', '2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-04-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-05-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-05-31', '2022-06-30', '2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-05-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-06-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-06-30', '2022-07-31', '2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-06-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-07-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-07-31', '2022-08-31', '2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-07-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-08-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-08-31', '2022-09-30', '2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-08-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-09-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-09-30', '2022-10-31', '2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-09-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-10-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-10-31', '2022-11-30', '2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-10-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-11-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-11-30', '2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-11-30 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2022-12-01 00:00:00
# Predictor test period: DatetimeIndex(['2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Predictor training period: 1997-01-31 00:00:00 to 2022-12-31 00:00:00
# Forecast target period: 1997-02-01 00:00:00 to 2023-01-01 00:00:00
# Predictor test period: DatetimeIndex([], dtype='datetime64[ns]', name='date', freq=None)

# %%
horizons = [1, 2, 3] # horizon


# function for forecasting:
def recursive_forecast(algorithm, hyperparameter, X_train, X_test, horizon = 3):
    """
    Create recursive forecast, here I'll forecast 3 horizons at once, then chop it back later to fit :)
    -> back 3 months from train set to forecast the 1st 3-horizon forecast for 2016-01
    Args:
    
    """
    forecast_df = pd.DataFrame()

    # Model:
    
    
# Iterate through the time series data
    for i in range(1, len(X_test) + horizon + 1):
    # Since range and .iloc don't cover the last value
        train_data = X_train.iloc[:len(X_train) - horizon + i, :]


            
        # Create and fit the SARIMAX model:
        model = SARIMAX(train_data, order=order, seasonal_order=seasonal_order, trend='n')
        model_fit = model.fit(disp = False)
        
            # Forecast h step ahead
            pred = model_fit.forecast(steps =h)
            print('Prediction: ', pred)
            forecasts.append(pred[-1])
        # Assign the forecasted values to a new column in the DataFrame
        forecast_df[f'Horizon_{h}'] = forecasts
        
    forecast_df['Real_obs'] = head_inf_test.values
    forecast_df.set_index(head_inf_test.index, inplace = True)

    for h in horizons:
        forecast_df[f'Error_horizon_{h}'] = forecast_df['Real_obs'] - forecast_df[f'Horizon_{h}']
    
    return forecast_df

# %%
# 5-fold for train data + 1 horizon:
from shutil import rmtree

from joblib import Memory

# Create a temporary folder to store the transformers of the pipeline
location = "cachedir"
memory = Memory(location=location, verbose=10)

tscv = TimeSeriesSplit(n_splits=5, test_size=6)

pipe_l = Pipeline(
    [
        ("scaling", StandardScaler()),
        ("regression", Lasso()),
    ])

param_grid = {
    'regression__alpha': np.arange(0.1, 0.2, 0.001)
}

grid = GridSearchCV(pipe_l, n_jobs=1, param_grid=param_grid, cv = tscv)
grid.fit(X_food_train, y_food_train)

# %%
grid.best_params_
# Out:
# {'regression__alpha': 0.1}

# %% [markdown]
# ---

# %%
services_f = HICP_class.loc[:, HICP_class.iloc[1, :] == 'Services']
energy_f = HICP_class.loc[:, HICP_class.iloc[1, :] == 'Energy']
negi_f = HICP_class.loc[:, HICP_class.iloc[1, :] == 'Non-energy industrial goods (NEIG)']

print('Number of items in food group: ', food_f.shape[1])
print('Number of items in services group: ', services_f.shape[1])
print('Number of items in energy group: ', energy_f.shape[1])
print('Number of items in Non-energy industrial goods (NEIG) group: ', negi_f.shape[1])
print('Total: ', food_f.shape[1] + services_f.shape[1]+ negi_f.shape[1] + energy_f.shape[1])

# %%
food_f = HICP_class.loc[:, HICP_class.iloc[0, :] == 'Food']
services_f = HICP_class.loc[:, HICP_class.iloc[1, :] == 'Services']
energy_f = HICP_class.loc[:, HICP_class.iloc[1, :] == 'Energy']
negi_f = HICP_class.loc[:, HICP_class.iloc[1, :] == 'Non-energy industrial goods (NEIG)']

print('Number of items in food group: ', food_f.shape[1])
print('Number of items in services group: ', services_f.shape[1])
print('Number of items in energy group: ', energy_f.shape[1])
print('Number of items in Non-energy industrial goods (NEIG) group: ', negi_f.shape[1])
print('Total: ', food_f.shape[1] + services_f.shape[1]+ negi_f.shape[1] + energy_f.shape[1])

# %%
# Second groups is for sets that doesn't contain missing values, so subset columns must appear in both df

food = HICP_yoy[HICP_yoy.columns.intersection(food_f.columns)]
services = HICP_yoy[HICP_yoy.columns.intersection(services_f.columns)]
energy = HICP_yoy[HICP_yoy.columns.intersection(energy_f.columns)]
negi = HICP_yoy[HICP_yoy.columns.intersection(negi_f.columns)]

print('Number of items in food group: ', food.shape[1])
print('Number of items in services group: ', services.shape[1])
print('Number of items in energy group: ', energy.shape[1])
print('Number of items in Non-energy industrial goods (NEIG) group: ', negi.shape[1])
print('Total: ', food.shape[1] + services.shape[1]+ negi.shape[1] + energy.shape[1])

# %%
food.head()

# %%
# Divide into train and test set

X_food_train = food[food.index <= '2015-12-31']
X_food_test = food[food.index > '2015-12-31']

#X_food_test = food[(food.index > '2015-12-31') & (food.index <= '2019-12-31')]
#food_df_t2 = food[(food.index > '2019-12-31') & (food.index <= '2021-12-31')]
#food_df_t3 = food[food.index > '2021-12-31']


services_train = services[services.index <= '2015-12-31']
services_t1 = services[(services.index > '2015-12-31') & (services.index <= '2019-12-31')]
services_t2 = services[(services.index > '2019-12-31') & (services.index <= '2021-12-31')]
services_t3 = services[services.index > '2021-12-31']


energy_train = energy[energy.index <= '2015-12-31']
energy_t1 = energy[(energy.index > '2015-12-31') & (energy.index <= '2019-12-31')]
energy_t2 = energy[(energy.index > '2019-12-31') & (energy.index <= '2021-12-31')]
energy_t3 = energy[energy.index > '2021-12-31']


negi_train = negi[negi.index <= '2015-12-31']
negi_t1 = negi[(negi.index > '2015-12-31') & (negi.index <= '2019-12-31')]
negi_t2 = negi[(negi.index > '2019-12-31') & (negi.index <= '2021-12-31')]
negi_t3 = negi[negi.index > '2021-12-31']

# %%
X_food_train = food[food.index <= '2015-12-31']
X_food_test = food[food.index > '2015-12-31']

y_food_train = food_series[food_series.index <= '2015-12-31']
y_food_test = food_series[food_series.index > '2015-12-31']

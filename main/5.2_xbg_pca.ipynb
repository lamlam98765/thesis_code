# %%
from os import chdir
chdir('/Users/lananhnguyen/Desktop/thesis/thesis_code')
import main.packages.mine_generic as mine_g
import main.packages.mine_specific as mine_s

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.preprocessing import StandardScaler

from sklearn.metrics import mean_squared_error, mean_absolute_error

import xgboost as xgb
import optuna
import json
from sklearn.decomposition import PCA

# %%
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
# Forecast:
def generate_forecast(X, y, N, T, h, hyperparam, verbose=1): # from common function
    """
    Generate recursive forecast
    """
    print(f"Horizon: {h}")
    print("------------------------")
    y_pred_series = []
    for i in range(0, T):  # T+1-h
        X_train = X.iloc[: N+i, :]
        y_train = y.iloc[h: N+i+h, :]

        X_test = X.iloc[N+i : N+i+1, :] 
        y_test = y.iloc[N+i+h : N+i+h+1, :]  

        if X_test.index[-1] > X.index[-1]-pd.DateOffset(months=h):
            break

        # Forecast:
        y_pred = mine_s.xgb_pred(X_train, X_test, y_train, y_test, hyperparam)

        if verbose == 1:
            print(f"Training period - features: {X_train.index[0]} to {X_train.index[-1]}")
            print(f"Training period - target : {y_train.index[0]} to {y_train.index[-1]}")
            print(f"Test period - features: {X_test.index}")
            print(f"Test period - target : {y_test.index}")
            print(f"Forecast: {y_pred}")
            print("-------------------------------------------------------")

        y_pred_series.append(y_pred[0])
    return y_pred_series

# %%
hicp_all_path = 'data/preprocessed/hicp_yoy.csv'
hicp_class_path = 'data/HICP_COICOP10s.xlsx'
model = 'xgb'
date_range = pd.date_range(start=mine_g.train_test_split_date + pd.DateOffset(months=1), end=mine_g.max_X_date, freq='M')

# %% [markdown]
# # Food:

# %%
category = 'Food'
cat_short = 'food'
hicp_cat_path = f'data/preprocessed/{cat_short}_yoy_infl.csv'
save_cat_file_path = f'data/forecast_results/{cat_short}_forecast.csv'

HICP_monthly, HICP_class, HICP_cat = mine_g.import_data_all(hicp_all_path=hicp_all_path,
                                                     hicp_class_path=hicp_class_path,
                                                     hicp_cat_path=hicp_cat_path)

cat_df = mine_g.split_into_category(category=category,
                             HICP_class=HICP_class,
                             HICP_monthly=HICP_monthly)
food_cat_prediction = pd.DataFrame(index=date_range)
# Out:
# Number of items in Food group:  180
# /Users/lananhnguyen/Desktop/thesis/thesis_code/main/packages/mine_generic.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df.fillna(0, inplace=True)

# %% [markdown]
# ## h = 1

# %%
h = 1

X_cat_train, X_cat_test, y_cat_train, y_cat_test = mine_g.split_train_test_set(X = cat_df, y = HICP_cat, h = h)
# Out:
# Horizon: 1
# Training predictor period: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training dependent variable period: 1997-02-28 00:00:00 to 2015-12-31 00:00:00

# %%
def prepare_X_train_test_pca(X_train, X_test, y, lags, n_components):

    # Scale data
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # PCA:
    pca = PCA(n_components = n_components)

    factor_train = pd.DataFrame(pca.fit_transform(X_train_scaled))
    factor_test = pd.DataFrame(pca.transform(X_test_scaled))

    # Create y_lagged:
    y_lagged = pd.DataFrame()
    for lag in range(0, lags + 1):
        y_lagged[f'Lag_{lag}'] = y[y.index <= mine_g.max_X_date].shift(lag)

    # concatenate all:
    X_factor_all = pd.concat([factor_train, factor_test], axis = 0, ignore_index=True)
    factor_col_name = {col: f'factor_{col}' for col in X_factor_all.columns}
    X_factor_all.rename(columns=factor_col_name, inplace=True)

    X_factor_lags_all = pd.concat([y_lagged.reset_index(), X_factor_all], axis=1)
    #X_factor_lags_all.set_index(0, drop=True)
    #X_factor_lags_all.dropna(inplace=True)
    X_factor_lags_all.set_index('date', drop=True, inplace=True)
    print(X_factor_lags_all.shape)
    return X_factor_lags_all

# %%
X_factor_lags_all = prepare_X_train_test_pca(X_cat_train, X_cat_test, HICP_cat, 3, 0.95)
X_cat_train_new = X_factor_lags_all[X_factor_lags_all.index.isin(X_cat_train.index)]
X_cat_test_new = X_factor_lags_all[X_factor_lags_all.index.isin(X_cat_test.index)]
# Out:
# (312, 37)

# %%
best_param = mine_s.hyperparam_tuning_optuna(mine_s.objective_xgb, X_cat_train_new, y_cat_train, scaler=False)

# save best_param:

with open(f'models/{model}_h_{h}_hyperparam.json', 'w') as json_file:
    json.dump(best_param, json_file)
# Out:
# Number of finished trials: 1000

# %%
# Forecast:

N, T = len(X_cat_train), len(X_cat_test)
y_pred = generate_forecast(X = X_factor_lags_all, y = HICP_cat, N = N, T = T, h = h, hyperparam=best_param, verbose=0)
food_cat_prediction.loc[:, f'{model}_{cat_short}_h_{h}'] = y_pred
# Out:
# Horizon: 1
# ------------------------

# %%
yoy_real = pd.read_csv(f"data/preprocessed/{cat_short}_yoy_infl.csv", parse_dates=True, index_col='date')
yoy_real_test = yoy_real[(yoy_real.index > mine_g.train_test_split_date) & (yoy_real.index <= mine_g.max_X_date)]

print(mean_absolute_error(yoy_real_test, y_pred))
print(np.sqrt(mean_squared_error(yoy_real_test, y_pred)))
# Out:
# 1.0243166385484817
# 1.8472940767679766

# %%
plt.figure(figsize=(14, 4))
plt.plot(yoy_real_test.reset_index(drop=True), label = "real")

plt.plot(y_pred, label = "h_1")
plt.legend()
plt.show()

# %% [markdown]
# ## h = 2

# %%
h = 2
X_cat_train, X_cat_test, y_cat_train, y_cat_test = mine_g.split_train_test_set(X = cat_df, y = HICP_cat, h = h)

best_param = mine_s.hyperparam_tuning_optuna(mine_s.objective_xgb, X_cat_train, y_cat_train)

# save best_param:

with open(f'models/{model}_h_{h}_hyperparam.json', 'w') as json_file:
    json.dump(best_param, json_file)

N, T = len(X_cat_train), len(X_cat_test)

y_pred = generate_forecast(X = cat_df, y = HICP_cat, N = N, T = T, h = h, hyperparam=best_param)
food_cat_prediction.loc[:, f'{model}_{cat_short}_h_{h}'] = y_pred
# Out:
# Horizon: 2
# Training predictor period: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training dependent variable period: 1997-03-31 00:00:00 to 2015-12-31 00:00:00
# Number of finished trials: 1000
# Horizon: 2
# ------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2015-12-31 00:00:00
# Test period - features: DatetimeIndex(['2015-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6842]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-01-31 00:00:00
# Test period - features: DatetimeIndex(['2015-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8971919]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-02-29 00:00:00
# Test period - features: DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0470113]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-03-31 00:00:00
# Test period - features: DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1949549]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-02-29 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-04-30 00:00:00
# Test period - features: DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2967929]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-05-31 00:00:00
# Test period - features: DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4002182]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-06-30 00:00:00
# Test period - features: DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.91011417]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-07-31 00:00:00
# Test period - features: DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0894983]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-08-31 00:00:00
# Test period - features: DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7084038]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-09-30 00:00:00
# Test period - features: DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6756989]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-10-31 00:00:00
# Test period - features: DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4844598]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-11-30 00:00:00
# Test period - features: DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9264293]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-12-31 00:00:00
# Test period - features: DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3788295]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-01-31 00:00:00
# Test period - features: DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4166926]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-02-28 00:00:00
# Test period - features: DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1611247]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-03-31 00:00:00
# Test period - features: DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4474554]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-04-30 00:00:00
# Test period - features: DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9705838]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-05-31 00:00:00
# Test period - features: DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4881388]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-06-30 00:00:00
# Test period - features: DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8007054]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-07-31 00:00:00
# Test period - features: DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1147063]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-08-31 00:00:00
# Test period - features: DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5937546]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-09-30 00:00:00
# Test period - features: DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1674097]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-10-31 00:00:00
# Test period - features: DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.0721662]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-11-30 00:00:00
# Test period - features: DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.4231775]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-12-31 00:00:00
# Test period - features: DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.348758]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-01-31 00:00:00
# Test period - features: DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.0734544]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-02-28 00:00:00
# Test period - features: DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9093379]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-03-31 00:00:00
# Test period - features: DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.45958]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-04-30 00:00:00
# Test period - features: DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9923183]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-05-31 00:00:00
# Test period - features: DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.2971969]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-06-30 00:00:00
# Test period - features: DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.5645716]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-07-31 00:00:00
# Test period - features: DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.730113]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-08-31 00:00:00
# Test period - features: DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.408921]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-09-30 00:00:00
# Test period - features: DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.5027955]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-10-31 00:00:00
# Test period - features: DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.6804128]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-11-30 00:00:00
# Test period - features: DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.418169]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-12-31 00:00:00
# Test period - features: DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7492479]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-01-31 00:00:00
# Test period - features: DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5652047]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-02-28 00:00:00
# Test period - features: DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4126314]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-03-31 00:00:00
# Test period - features: DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3485206]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-04-30 00:00:00
# Test period - features: DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.9706521]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-05-31 00:00:00
# Test period - features: DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0931307]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-06-30 00:00:00
# Test period - features: DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1511483]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-07-31 00:00:00
# Test period - features: DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1131905]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-08-31 00:00:00
# Test period - features: DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8573867]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-09-30 00:00:00
# Test period - features: DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4141173]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-10-31 00:00:00
# Test period - features: DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0290972]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-11-30 00:00:00
# Test period - features: DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7640868]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-12-31 00:00:00
# Test period - features: DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.2140467]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-01-31 00:00:00
# Test period - features: DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7043562]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-02-29 00:00:00
# Test period - features: DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.5079432]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-03-31 00:00:00
# Test period - features: DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.0442555]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-02-29 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-04-30 00:00:00
# Test period - features: DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.2899075]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-05-31 00:00:00
# Test period - features: DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.8928874]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-06-30 00:00:00
# Test period - features: DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.2014043]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-07-31 00:00:00
# Test period - features: DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.1674578]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-08-31 00:00:00
# Test period - features: DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3423748]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-09-30 00:00:00
# Test period - features: DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5665531]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-10-31 00:00:00
# Test period - features: DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.0622766]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-11-30 00:00:00
# Test period - features: DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0394865]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-12-31 00:00:00
# Test period - features: DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0771939]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-01-31 00:00:00
# Test period - features: DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.463624]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-02-28 00:00:00
# Test period - features: DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5873468]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-03-31 00:00:00
# Test period - features: DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.038567]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-04-30 00:00:00
# Test period - features: DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1343877]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-05-31 00:00:00
# Test period - features: DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.2403498]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-06-30 00:00:00
# Test period - features: DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9262065]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-07-31 00:00:00
# Test period - features: DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9417106]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-08-31 00:00:00
# Test period - features: DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.8701024]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-09-30 00:00:00
# Test period - features: DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.78966]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-10-31 00:00:00
# Test period - features: DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.7360892]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-11-30 00:00:00
# Test period - features: DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.1738927]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-12-31 00:00:00
# Test period - features: DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.4498577]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-01-31 00:00:00
# Test period - features: DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.1655245]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-02-28 00:00:00
# Test period - features: DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.1702237]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-03-31 00:00:00
# Test period - features: DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.9521372]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-04-30 00:00:00
# Test period - features: DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.642896]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-05-31 00:00:00
# Test period - features: DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.4700675]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-06-30 00:00:00
# Test period - features: DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.1379695]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-07-31 00:00:00
# Test period - features: DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.9288886]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-08-31 00:00:00
# Test period - features: DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [6.53464]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-09-30 00:00:00
# Test period - features: DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [6.7451158]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-10-31 00:00:00
# Test period - features: DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [9.46963]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-11-30 00:00:00
# Test period - features: DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [10.162384]
# -------------------------------------------------------

# %% [markdown]
# ## h = 3

# %%
h = 3
X_cat_train, X_cat_test, y_cat_train, y_cat_test = mine_g.split_train_test_set(X = cat_df, y = HICP_cat, h = h)

best_param = mine_s.hyperparam_tuning_optuna(mine_s.objective_xgb, X_cat_train, y_cat_train)

# save best_param:

with open(f'models/{model}_h_{h}_hyperparam.json', 'w') as json_file:
    json.dump(best_param, json_file)

N, T = len(X_cat_train), len(X_cat_test)

y_pred = generate_forecast(X = cat_df, y = HICP_cat, N = N, T = T, h = h, hyperparam=best_param)
food_cat_prediction.loc[:, f'{model}_{cat_short}_h_{h}'] = y_pred
# Out:
# Horizon: 3
# Training predictor period: 1997-01-31 00:00:00 to 2015-09-30 00:00:00
# Training dependent variable period: 1997-04-30 00:00:00 to 2015-12-31 00:00:00
# Number of finished trials: 1000
# Horizon: 3
# ------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2015-12-31 00:00:00
# Test period - features: DatetimeIndex(['2015-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3273658]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-01-31 00:00:00
# Test period - features: DatetimeIndex(['2015-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.88729024]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-02-29 00:00:00
# Test period - features: DatetimeIndex(['2015-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.77279633]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-03-31 00:00:00
# Test period - features: DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2322488]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-04-30 00:00:00
# Test period - features: DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4640553]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-02-29 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-05-31 00:00:00
# Test period - features: DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1953943]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-06-30 00:00:00
# Test period - features: DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3696773]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-07-31 00:00:00
# Test period - features: DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0446883]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-08-31 00:00:00
# Test period - features: DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2436854]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-09-30 00:00:00
# Test period - features: DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4073343]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-10-31 00:00:00
# Test period - features: DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5595646]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-11-30 00:00:00
# Test period - features: DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8030665]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2016-12-31 00:00:00
# Test period - features: DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8470991]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-01-31 00:00:00
# Test period - features: DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7698792]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-02-28 00:00:00
# Test period - features: DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6393327]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-03-31 00:00:00
# Test period - features: DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9372901]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-04-30 00:00:00
# Test period - features: DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.913477]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-02-28 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-05-31 00:00:00
# Test period - features: DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9008423]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-06-30 00:00:00
# Test period - features: DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7244108]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-07-31 00:00:00
# Test period - features: DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3518407]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-08-31 00:00:00
# Test period - features: DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1670184]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-09-30 00:00:00
# Test period - features: DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.2809052]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-10-31 00:00:00
# Test period - features: DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.348692]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-11-30 00:00:00
# Test period - features: DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.6050966]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2017-12-31 00:00:00
# Test period - features: DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.2891784]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-01-31 00:00:00
# Test period - features: DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3156002]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-02-28 00:00:00
# Test period - features: DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7726803]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-03-31 00:00:00
# Test period - features: DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.13687]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-04-30 00:00:00
# Test period - features: DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3676102]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-02-28 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-05-31 00:00:00
# Test period - features: DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.7876048]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-06-30 00:00:00
# Test period - features: DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.4135249]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-07-31 00:00:00
# Test period - features: DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.2797246]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-08-31 00:00:00
# Test period - features: DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.4082642]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-09-30 00:00:00
# Test period - features: DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.59788]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-10-31 00:00:00
# Test period - features: DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.6529183]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-11-30 00:00:00
# Test period - features: DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3908126]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2018-12-31 00:00:00
# Test period - features: DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9039719]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-01-31 00:00:00
# Test period - features: DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.167262]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-02-28 00:00:00
# Test period - features: DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3926811]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-03-31 00:00:00
# Test period - features: DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.59852684]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-04-30 00:00:00
# Test period - features: DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1112666]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-02-28 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-05-31 00:00:00
# Test period - features: DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.549901]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-06-30 00:00:00
# Test period - features: DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.224188]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-07-31 00:00:00
# Test period - features: DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1995342]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-08-31 00:00:00
# Test period - features: DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1183686]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-09-30 00:00:00
# Test period - features: DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0981654]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-10-31 00:00:00
# Test period - features: DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3579195]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-11-30 00:00:00
# Test period - features: DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4189866]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-12-31 00:00:00
# Test period - features: DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5365719]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-01-31 00:00:00
# Test period - features: DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9973305]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-02-29 00:00:00
# Test period - features: DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5061737]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-03-31 00:00:00
# Test period - features: DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1827197]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-04-30 00:00:00
# Test period - features: DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7716522]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-02-29 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-05-31 00:00:00
# Test period - features: DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3347778]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-06-30 00:00:00
# Test period - features: DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.2893078]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-07-31 00:00:00
# Test period - features: DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.017663]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-08-31 00:00:00
# Test period - features: DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.458056]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-09-30 00:00:00
# Test period - features: DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3955507]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-10-31 00:00:00
# Test period - features: DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9315702]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-11-30 00:00:00
# Test period - features: DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5115693]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-12-31 00:00:00
# Test period - features: DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2604034]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-01-31 00:00:00
# Test period - features: DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6999382]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-02-28 00:00:00
# Test period - features: DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.79626304]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-03-31 00:00:00
# Test period - features: DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1851783]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-04-30 00:00:00
# Test period - features: DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1569092]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-02-28 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-05-31 00:00:00
# Test period - features: DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.0443313]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-06-30 00:00:00
# Test period - features: DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6294394]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-07-31 00:00:00
# Test period - features: DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.5027308]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-08-31 00:00:00
# Test period - features: DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.0225668]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-09-30 00:00:00
# Test period - features: DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.1551397]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-10-31 00:00:00
# Test period - features: DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.8243556]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-11-30 00:00:00
# Test period - features: DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.7312796]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-12-31 00:00:00
# Test period - features: DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.0278933]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-01-31 00:00:00
# Test period - features: DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.4092183]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-02-28 00:00:00
# Test period - features: DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.3150094]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-03-31 00:00:00
# Test period - features: DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.70823]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-04-30 00:00:00
# Test period - features: DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.2427635]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-02-28 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-05-31 00:00:00
# Test period - features: DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.136117]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-06-30 00:00:00
# Test period - features: DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.0695777]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-07-31 00:00:00
# Test period - features: DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.929259]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-08-31 00:00:00
# Test period - features: DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.7951107]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-09-30 00:00:00
# Test period - features: DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [7.938904]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-10-31 00:00:00
# Test period - features: DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [8.797004]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-11-30 00:00:00
# Test period - features: DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [11.217325]
# -------------------------------------------------------

# %%
food_cat_prediction
# Out:
#             xgb_food_h_1  xgb_food_h_2  xgb_food_h_3
# 2016-01-31      1.456735      1.684200      1.327366
# 2016-02-29      1.561387      0.897192      0.887290
# 2016-03-31      1.489828      1.047011      0.772796
# 2016-04-30      1.040370      1.194955      1.232249
# 2016-05-31      1.005898      1.296793      1.464055
# ...                  ...           ...           ...
# 2022-08-31      6.435944      3.928889      4.929259
# 2022-09-30      7.501304      6.534640      4.795111
# 2022-10-31      9.717562      6.745116      7.938904
# 2022-11-30     11.234087      9.469630      8.797004
# 2022-12-31     11.576380     10.162384     11.217325
#
# [84 rows x 3 columns]

# %%
mine_g.save_forecast(forecast_result_df=food_cat_prediction.reset_index(drop=True), cat_file_path=save_cat_file_path, category=cat_short)

# %% [markdown]
# ------------------

# %% [markdown]
# # Energy:

# %%
category = 'Energy'
cat_short = 'energy'
hicp_cat_path = f'data/preprocessed/{cat_short}_yoy_infl.csv'
save_cat_file_path = f'data/forecast_results/{cat_short}_forecast.csv'

HICP_monthly, HICP_class, HICP_cat = mine_g.import_data_all(hicp_all_path=hicp_all_path,
                                                     hicp_class_path=hicp_class_path,
                                                     hicp_cat_path=hicp_cat_path)

cat_df = mine_g.split_into_category(category=category,
                             HICP_class=HICP_class,
                             HICP_monthly=HICP_monthly)
energy_cat_prediction = pd.DataFrame(index=date_range)
# Out:
# Number of items in Energy group:  14
# /Users/lananhnguyen/Desktop/thesis/thesis_code/main/packages/mine_generic.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df.fillna(0, inplace=True)

# %%
h = 1
#cat_df = pd.merge(cat_df, HICP_cat, how='inner', left_index=True, right_index=True)
X_cat_train, X_cat_test, y_cat_train, y_cat_test = mine_g.split_train_test_set(X = cat_df, y = HICP_cat, h = h)

X_factor_lags_all = prepare_X_train_test_pca(X_cat_train, X_cat_test, HICP_cat, 3, 0.95)
X_cat_train_new = X_factor_lags_all[X_factor_lags_all.index.isin(X_cat_train.index)]


best_param = mine_s.hyperparam_tuning_optuna(mine_s.objective_xgb, X_cat_train_new, y_cat_train)
N, T = len(X_cat_train_new), len(X_cat_test)

y_pred = generate_forecast(X = X_factor_lags_all, y = HICP_cat, N = N, T = T, h = h, hyperparam=best_param)
energy_cat_prediction.loc[:, f'{model}_{cat_short}_h_{h}'] = y_pred
# Out:
# Horizon: 1
# Training predictor period: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training dependent variable period: 1997-02-28 00:00:00 to 2015-12-31 00:00:00
# (312, 11)
# Number of finished trials: 1000
# Horizon: 1
# ------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2015-12-31 00:00:00
# Test period - features: DatetimeIndex(['2015-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.5563126]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-01-31 00:00:00
# Test period - features: DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.7732735]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-02-29 00:00:00
# Test period - features: DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.8445215]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-02-29 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-03-31 00:00:00
# Test period - features: DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-7.436041]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-04-30 00:00:00
# Test period - features: DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.638259]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-05-31 00:00:00
# Test period - features: DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-7.346112]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-06-30 00:00:00
# Test period - features: DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.655383]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-07-31 00:00:00
# Test period - features: DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.6333365]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-08-31 00:00:00
# Test period - features: DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.4464617]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-09-30 00:00:00
# Test period - features: DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-4.359286]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-10-31 00:00:00
# Test period - features: DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.7459459]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-11-30 00:00:00
# Test period - features: DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-2.3310843]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-12-31 00:00:00
# Test period - features: DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.0157135]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-01-31 00:00:00
# Test period - features: DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.771207]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-02-28 00:00:00
# Test period - features: DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [6.569704]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-03-31 00:00:00
# Test period - features: DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.517292]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-04-30 00:00:00
# Test period - features: DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.2204185]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-05-31 00:00:00
# Test period - features: DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.885686]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-06-30 00:00:00
# Test period - features: DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2193382]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-07-31 00:00:00
# Test period - features: DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4662224]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-08-31 00:00:00
# Test period - features: DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8267856]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-09-30 00:00:00
# Test period - features: DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.4129794]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-10-31 00:00:00
# Test period - features: DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.81140053]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-11-30 00:00:00
# Test period - features: DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.9838564]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-12-31 00:00:00
# Test period - features: DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8212688]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-01-31 00:00:00
# Test period - features: DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.30797288]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-02-28 00:00:00
# Test period - features: DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.06179039]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-03-31 00:00:00
# Test period - features: DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-1.0823178]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-04-30 00:00:00
# Test period - features: DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.967532]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-05-31 00:00:00
# Test period - features: DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.707448]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-06-30 00:00:00
# Test period - features: DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [6.0718603]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-07-31 00:00:00
# Test period - features: DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.998643]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-08-31 00:00:00
# Test period - features: DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [6.808486]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-09-30 00:00:00
# Test period - features: DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [6.0106716]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-10-31 00:00:00
# Test period - features: DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [10.090354]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-11-30 00:00:00
# Test period - features: DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [9.952624]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-12-31 00:00:00
# Test period - features: DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [6.558688]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-01-31 00:00:00
# Test period - features: DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.4273777]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-02-28 00:00:00
# Test period - features: DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.5740173]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-03-31 00:00:00
# Test period - features: DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.6702993]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-04-30 00:00:00
# Test period - features: DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.7027638]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-05-31 00:00:00
# Test period - features: DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.4109776]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-06-30 00:00:00
# Test period - features: DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.1007483]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-07-31 00:00:00
# Test period - features: DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.8254986]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-08-31 00:00:00
# Test period - features: DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.8242087]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-09-30 00:00:00
# Test period - features: DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-1.6804888]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-10-31 00:00:00
# Test period - features: DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-2.523761]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-11-30 00:00:00
# Test period - features: DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.8339534]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-12-31 00:00:00
# Test period - features: DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.54998857]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-01-31 00:00:00
# Test period - features: DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.7866857]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-02-29 00:00:00
# Test period - features: DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.7204235]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-02-29 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-03-31 00:00:00
# Test period - features: DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-1.1517117]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-04-30 00:00:00
# Test period - features: DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.730011]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-05-31 00:00:00
# Test period - features: DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.595585]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-06-30 00:00:00
# Test period - features: DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.6260443]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-07-31 00:00:00
# Test period - features: DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-7.629097]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-08-31 00:00:00
# Test period - features: DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.36115]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-09-30 00:00:00
# Test period - features: DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.898167]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-10-31 00:00:00
# Test period - features: DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-7.343919]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-11-30 00:00:00
# Test period - features: DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.6221566]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-12-31 00:00:00
# Test period - features: DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-7.0991564]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-01-31 00:00:00
# Test period - features: DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-1.0841373]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-02-28 00:00:00
# Test period - features: DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.85160804]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-03-31 00:00:00
# Test period - features: DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.733373]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-04-30 00:00:00
# Test period - features: DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [8.840919]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-05-31 00:00:00
# Test period - features: DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [8.222843]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-06-30 00:00:00
# Test period - features: DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [9.364015]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-07-31 00:00:00
# Test period - features: DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [10.503566]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-08-31 00:00:00
# Test period - features: DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [12.002895]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-09-30 00:00:00
# Test period - features: DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [11.015453]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-10-31 00:00:00
# Test period - features: DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [13.01104]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-11-30 00:00:00
# Test period - features: DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [15.237305]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-12-31 00:00:00
# Test period - features: DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [15.427164]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-01-31 00:00:00
# Test period - features: DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [13.448416]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-02-28 00:00:00
# Test period - features: DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [14.786358]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-03-31 00:00:00
# Test period - features: DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [19.521084]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-04-30 00:00:00
# Test period - features: DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [24.642033]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-05-31 00:00:00
# Test period - features: DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [25.838722]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-06-30 00:00:00
# Test period - features: DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [27.017931]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-07-31 00:00:00
# Test period - features: DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [31.193018]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-08-31 00:00:00
# Test period - features: DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [32.70391]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-09-30 00:00:00
# Test period - features: DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [34.9151]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-10-31 00:00:00
# Test period - features: DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [36.930042]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-11-30 00:00:00
# Test period - features: DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [35.946625]
# -------------------------------------------------------

# %%
for h in [1, 2, 3]:
    X_cat_train, X_cat_test, y_cat_train, y_cat_test = mine_g.split_train_test_set(X = cat_df, y = HICP_cat, h = h)

    best_param = mine_s.hyperparam_tuning_optuna(mine_s.objective_xgb, X_cat_train, y_cat_train)

    # save best_param:

    with open(f'models/{model}_h_{h}_hyperparam.json', 'w') as json_file:
        json.dump(best_param, json_file)

    N, T = len(X_cat_train), len(X_cat_test)

    y_pred = generate_forecast(X = cat_df, y = HICP_cat, N = N, T = T, h = h, hyperparam=best_param)
    energy_cat_prediction.loc[:, f'{model}_{cat_short}_h_{h}'] = y_pred
# Out:
# Horizon: 1
# Training predictor period: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training dependent variable period: 1997-02-28 00:00:00 to 2015-12-31 00:00:00
# Number of finished trials: 1000
# Horizon: 1
# ------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2015-12-31 00:00:00
# Test period - features: DatetimeIndex(['2015-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.0335536]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-01-31 00:00:00
# Test period - features: DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-4.4353023]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-02-29 00:00:00
# Test period - features: DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-7.7535896]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-02-29 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-03-31 00:00:00
# Test period - features: DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-7.6003914]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-04-30 00:00:00
# Test period - features: DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-8.201786]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-05-31 00:00:00
# Test period - features: DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.6104083]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-06-30 00:00:00
# Test period - features: DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-4.118983]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-07-31 00:00:00
# Test period - features: DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-3.453441]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-08-31 00:00:00
# Test period - features: DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-4.085834]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-09-30 00:00:00
# Test period - features: DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-2.1540132]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-10-31 00:00:00
# Test period - features: DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.76736057]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-11-30 00:00:00
# Test period - features: DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-1.4357446]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-12-31 00:00:00
# Test period - features: DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.1928563]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-01-31 00:00:00
# Test period - features: DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [7.2695003]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-02-28 00:00:00
# Test period - features: DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [8.658743]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-03-31 00:00:00
# Test period - features: DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [6.0169053]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-04-30 00:00:00
# Test period - features: DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.2999053]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-05-31 00:00:00
# Test period - features: DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.5429192]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-06-30 00:00:00
# Test period - features: DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5899457]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-07-31 00:00:00
# Test period - features: DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.516106]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-08-31 00:00:00
# Test period - features: DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.7226906]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-09-30 00:00:00
# Test period - features: DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.8614872]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-10-31 00:00:00
# Test period - features: DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7841518]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-11-30 00:00:00
# Test period - features: DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.2537017]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-12-31 00:00:00
# Test period - features: DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3754406]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-01-31 00:00:00
# Test period - features: DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1249015]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-02-28 00:00:00
# Test period - features: DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.12925175]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-03-31 00:00:00
# Test period - features: DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.37615293]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-04-30 00:00:00
# Test period - features: DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5198731]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-05-31 00:00:00
# Test period - features: DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.4090447]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-06-30 00:00:00
# Test period - features: DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [6.3812213]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-07-31 00:00:00
# Test period - features: DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [6.9566107]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-08-31 00:00:00
# Test period - features: DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [7.891042]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-09-30 00:00:00
# Test period - features: DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [7.4913015]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-10-31 00:00:00
# Test period - features: DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [7.8264093]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-11-30 00:00:00
# Test period - features: DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [8.782776]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-12-31 00:00:00
# Test period - features: DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.7407246]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-01-31 00:00:00
# Test period - features: DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.886629]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-02-28 00:00:00
# Test period - features: DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.1143866]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-03-31 00:00:00
# Test period - features: DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.4882255]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-04-30 00:00:00
# Test period - features: DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.15106]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-05-31 00:00:00
# Test period - features: DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.8753824]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-06-30 00:00:00
# Test period - features: DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.8123114]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-07-31 00:00:00
# Test period - features: DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1974077]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-08-31 00:00:00
# Test period - features: DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.18067646]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-09-30 00:00:00
# Test period - features: DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.35388255]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-10-31 00:00:00
# Test period - features: DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-1.3244767]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-11-30 00:00:00
# Test period - features: DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.0000887]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-12-31 00:00:00
# Test period - features: DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.4578899]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-01-31 00:00:00
# Test period - features: DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.7387033]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-02-29 00:00:00
# Test period - features: DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.196458]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-02-29 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-03-31 00:00:00
# Test period - features: DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.815755]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-04-30 00:00:00
# Test period - features: DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.6554203]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-05-31 00:00:00
# Test period - features: DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-7.3299794]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-06-30 00:00:00
# Test period - features: DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.799947]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-07-31 00:00:00
# Test period - features: DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.380362]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-08-31 00:00:00
# Test period - features: DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.775239]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-09-30 00:00:00
# Test period - features: DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-7.079337]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-10-31 00:00:00
# Test period - features: DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.824317]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-11-30 00:00:00
# Test period - features: DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-7.3352404]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-12-31 00:00:00
# Test period - features: DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.752885]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-01-31 00:00:00
# Test period - features: DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.31805283]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-02-28 00:00:00
# Test period - features: DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5992174]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-03-31 00:00:00
# Test period - features: DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [6.465295]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-04-30 00:00:00
# Test period - features: DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [7.5162196]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-05-31 00:00:00
# Test period - features: DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [8.752404]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-06-30 00:00:00
# Test period - features: DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [10.152842]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-07-31 00:00:00
# Test period - features: DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [11.59218]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-08-31 00:00:00
# Test period - features: DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [11.92729]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-09-30 00:00:00
# Test period - features: DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [12.5856905]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-10-31 00:00:00
# Test period - features: DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [13.682899]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-11-30 00:00:00
# Test period - features: DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [14.932709]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-12-31 00:00:00
# Test period - features: DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [15.783421]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-01-31 00:00:00
# Test period - features: DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [14.230893]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-02-28 00:00:00
# Test period - features: DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [17.422415]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-03-31 00:00:00
# Test period - features: DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [20.738436]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-04-30 00:00:00
# Test period - features: DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [23.239977]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-05-31 00:00:00
# Test period - features: DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [25.94115]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-06-30 00:00:00
# Test period - features: DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [27.851421]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-07-31 00:00:00
# Test period - features: DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [29.527771]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-08-31 00:00:00
# Test period - features: DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [31.542278]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-09-30 00:00:00
# Test period - features: DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [33.063725]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-10-31 00:00:00
# Test period - features: DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [35.03714]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-11-30 00:00:00
# Test period - features: DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [34.542606]
# -------------------------------------------------------
# Horizon: 2
# Training predictor period: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training dependent variable period: 1997-03-31 00:00:00 to 2015-12-31 00:00:00
# Number of finished trials: 1000
# Horizon: 2
# ------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2015-12-31 00:00:00
# Test period - features: DatetimeIndex(['2015-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.989275]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-01-31 00:00:00
# Test period - features: DatetimeIndex(['2015-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.7777934]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-02-29 00:00:00
# Test period - features: DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.0528145]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-03-31 00:00:00
# Test period - features: DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.802638]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-02-29 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-04-30 00:00:00
# Test period - features: DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.818075]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-05-31 00:00:00
# Test period - features: DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-7.1407084]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-06-30 00:00:00
# Test period - features: DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.9354854]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-07-31 00:00:00
# Test period - features: DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-3.7460146]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-08-31 00:00:00
# Test period - features: DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-3.5374455]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-09-30 00:00:00
# Test period - features: DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-3.036794]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-10-31 00:00:00
# Test period - features: DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-1.7338809]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-11-30 00:00:00
# Test period - features: DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.97667074]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-12-31 00:00:00
# Test period - features: DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-1.060485]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-01-31 00:00:00
# Test period - features: DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.9765847]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-02-28 00:00:00
# Test period - features: DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.9923053]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-03-31 00:00:00
# Test period - features: DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.6956606]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-04-30 00:00:00
# Test period - features: DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.807314]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-05-31 00:00:00
# Test period - features: DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.705704]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-06-30 00:00:00
# Test period - features: DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.4183393]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-07-31 00:00:00
# Test period - features: DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3323693]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-08-31 00:00:00
# Test period - features: DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.0248752]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-09-30 00:00:00
# Test period - features: DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.4489653]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-10-31 00:00:00
# Test period - features: DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5959921]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-11-30 00:00:00
# Test period - features: DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.809671]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-12-31 00:00:00
# Test period - features: DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.48713]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-01-31 00:00:00
# Test period - features: DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1449893]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-02-28 00:00:00
# Test period - features: DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.50815773]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-03-31 00:00:00
# Test period - features: DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.6831225]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-04-30 00:00:00
# Test period - features: DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# ...
# Training period - target : 1997-04-30 00:00:00 to 2019-10-31 00:00:00
# Test period - features: DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.5859111]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-11-30 00:00:00
# Test period - features: DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-4.3259745]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-12-31 00:00:00
# Test period - features: DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-3.002242]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-01-31 00:00:00
# Test period - features: DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.5377574]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-02-29 00:00:00
# Test period - features: DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.12441811]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-03-31 00:00:00
# Test period - features: DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.4860873]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-04-30 00:00:00
# Test period - features: DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6232492]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-02-29 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-05-31 00:00:00
# Test period - features: DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.08647645]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-06-30 00:00:00
# Test period - features: DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-3.7620623]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-07-31 00:00:00
# Test period - features: DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.435168]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-08-31 00:00:00
# Test period - features: DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.0423117]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-09-30 00:00:00
# Test period - features: DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.7479477]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-10-31 00:00:00
# Test period - features: DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.374867]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-11-30 00:00:00
# Test period - features: DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.816516]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-12-31 00:00:00
# Test period - features: DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-6.4559793]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-01-31 00:00:00
# Test period - features: DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-5.746187]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-02-28 00:00:00
# Test period - features: DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-4.0798416]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-03-31 00:00:00
# Test period - features: DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-3.9268665]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-04-30 00:00:00
# Test period - features: DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6831203]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-02-28 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-05-31 00:00:00
# Test period - features: DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.4028893]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-06-30 00:00:00
# Test period - features: DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [5.278567]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-07-31 00:00:00
# Test period - features: DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [9.782879]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-08-31 00:00:00
# Test period - features: DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [7.2611375]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-09-30 00:00:00
# Test period - features: DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [10.008641]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-10-31 00:00:00
# Test period - features: DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [12.066054]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-11-30 00:00:00
# Test period - features: DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [11.585673]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-12-31 00:00:00
# Test period - features: DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [14.200258]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-01-31 00:00:00
# Test period - features: DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [11.624703]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-02-28 00:00:00
# Test period - features: DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [16.580261]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-03-31 00:00:00
# Test period - features: DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [18.518948]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-04-30 00:00:00
# Test period - features: DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [20.766083]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-02-28 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-05-31 00:00:00
# Test period - features: DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [23.014843]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-06-30 00:00:00
# Test period - features: DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [25.882929]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-07-31 00:00:00
# Test period - features: DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [27.126225]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-08-31 00:00:00
# Test period - features: DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [27.638664]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-09-30 00:00:00
# Test period - features: DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [25.422089]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-10-31 00:00:00
# Test period - features: DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [30.271833]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-11-30 00:00:00
# Test period - features: DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [34.434204]
# -------------------------------------------------------

# %%
mine_g.save_forecast(forecast_result_df=energy_cat_prediction.reset_index(drop=True), cat_file_path=save_cat_file_path, category=cat_short)

# %%
yoy_real = pd.read_csv(f"data/preprocessed/{cat_short}_yoy_infl.csv", parse_dates=True, index_col='date')
yoy_real_test = yoy_real[(yoy_real.index > mine_g.train_test_split_date) & (yoy_real.index <= mine_g.max_X_date)]
#df_compare = pd.concat([energy_cat_prediction, yoy_real_test], axis = 1)

print(mean_absolute_error(yoy_real_test,energy_cat_prediction.iloc[:, 0]))
print(np.sqrt(mean_squared_error(yoy_real_test,energy_cat_prediction.iloc[:, 0])))
# Out:
# 3.157294252673164
# 4.954443730805477

# %% [markdown]
# ## NEIG:

# %%
cat_short = 'neig'
category = 'Non-energy industrial goods (NEIG)'
hicp_cat_path = f'data/preprocessed/{cat_short}_yoy_infl.csv'
save_cat_file_path = f'data/forecast_results/{cat_short}_forecast.csv'

HICP_monthly, HICP_class, HICP_cat = mine_g.import_data_all(hicp_all_path=hicp_all_path,
                                                     hicp_class_path=hicp_class_path,
                                                     hicp_cat_path=hicp_cat_path)

cat_df = mine_g.split_into_category(category=category,
                             HICP_class=HICP_class,
                             HICP_monthly=HICP_monthly)
neig_cat_prediction = pd.DataFrame(index=date_range)
# Out:
# Number of items in Non-energy industrial goods (NEIG) group:  302
# /Users/lananhnguyen/Desktop/thesis/thesis_code/main/packages/mine_generic.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df.fillna(0, inplace=True)

# %%
h = 1

X_cat_train, X_cat_test, y_cat_train, y_cat_test = mine_g.split_train_test_set(X = cat_df, y = HICP_cat, h = h)

X_factor_lags_all = prepare_X_train_test_pca(X_cat_train, X_cat_test, HICP_cat, 3, 0.95)
X_cat_train_new = X_factor_lags_all[X_factor_lags_all.index.isin(X_cat_train.index)]


best_param = mine_s.hyperparam_tuning_optuna(mine_s.objective_xgb, X_cat_train_new, y_cat_train)
N, T = len(X_cat_train_new), len(X_cat_test)

y_pred = generate_forecast(X = X_factor_lags_all, y = HICP_cat, N = N, T = T, h = h, hyperparam=best_param)
energy_cat_prediction.loc[:, f'{model}_{cat_short}_h_{h}'] = y_pred

# %%
for h in [1, 2, 3]:
    X_cat_train, X_cat_test, y_cat_train, y_cat_test = mine_g.split_train_test_set(X = cat_df, y = HICP_cat, h = h)

    best_param = mine_s.hyperparam_tuning_optuna(mine_s.objective_xgb, X_cat_train, y_cat_train)

    # save best_param:

    with open(f'models/{model}_h_{h}_hyperparam.json', 'w') as json_file:
        json.dump(best_param, json_file)

    N, T = len(X_cat_train), len(X_cat_test)

    y_pred = generate_forecast(X = cat_df, y = HICP_cat, N = N, T = T, h = h, hyperparam=best_param)
    neig_cat_prediction.loc[:, f'{model}_{cat_short}_h_{h}'] = y_pred
# Out:
# Horizon: 1
# Training predictor period: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training dependent variable period: 1997-02-28 00:00:00 to 2015-12-31 00:00:00
# Number of finished trials: 1000
# Horizon: 1
# ------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2015-12-31 00:00:00
# Test period - features: DatetimeIndex(['2015-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8298437]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-01-31 00:00:00
# Test period - features: DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.72592443]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-02-29 00:00:00
# Test period - features: DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.6916368]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-02-29 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-03-31 00:00:00
# Test period - features: DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.5020294]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-04-30 00:00:00
# Test period - features: DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.679359]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-05-31 00:00:00
# Test period - features: DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.44315368]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-06-30 00:00:00
# Test period - features: DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7197816]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-07-31 00:00:00
# Test period - features: DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.5659056]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-08-31 00:00:00
# Test period - features: DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.6443062]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-09-30 00:00:00
# Test period - features: DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.35801712]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-10-31 00:00:00
# Test period - features: DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.53821576]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-11-30 00:00:00
# Test period - features: DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.49908048]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-12-31 00:00:00
# Test period - features: DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.5391418]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-01-31 00:00:00
# Test period - features: DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8765227]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-02-28 00:00:00
# Test period - features: DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.64415145]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-03-31 00:00:00
# Test period - features: DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.75575083]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-04-30 00:00:00
# Test period - features: DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.60197204]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-05-31 00:00:00
# Test period - features: DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7586154]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-06-30 00:00:00
# Test period - features: DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8437307]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-07-31 00:00:00
# Test period - features: DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.699418]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-08-31 00:00:00
# Test period - features: DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.3794187]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-09-30 00:00:00
# Test period - features: DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.74673134]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-10-31 00:00:00
# Test period - features: DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.9716725]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-11-30 00:00:00
# Test period - features: DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.84559387]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-12-31 00:00:00
# Test period - features: DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7137911]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-01-31 00:00:00
# Test period - features: DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7427126]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-02-28 00:00:00
# Test period - features: DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.67420757]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-03-31 00:00:00
# Test period - features: DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.46250635]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-04-30 00:00:00
# Test period - features: DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.5750935]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-05-31 00:00:00
# Test period - features: DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.5235627]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-06-30 00:00:00
# Test period - features: DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.4576865]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-07-31 00:00:00
# Test period - features: DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.60980827]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-08-31 00:00:00
# Test period - features: DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7884799]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-09-30 00:00:00
# Test period - features: DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.70112365]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-10-31 00:00:00
# Test period - features: DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.54026437]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-11-30 00:00:00
# Test period - features: DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7880261]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-12-31 00:00:00
# Test period - features: DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.77322847]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-01-31 00:00:00
# Test period - features: DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.93616915]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-02-28 00:00:00
# Test period - features: DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.97848064]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-03-31 00:00:00
# Test period - features: DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.4955232]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-04-30 00:00:00
# Test period - features: DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8609395]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-05-31 00:00:00
# Test period - features: DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.83508915]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-06-30 00:00:00
# Test period - features: DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.96046114]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-07-31 00:00:00
# Test period - features: DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.67674047]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-08-31 00:00:00
# Test period - features: DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.75502676]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-09-30 00:00:00
# Test period - features: DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.862078]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-10-31 00:00:00
# Test period - features: DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.4350775]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-11-30 00:00:00
# Test period - features: DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7650079]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-12-31 00:00:00
# Test period - features: DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7094164]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-01-31 00:00:00
# Test period - features: DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.9845412]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-02-29 00:00:00
# Test period - features: DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.9306757]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-02-29 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-03-31 00:00:00
# Test period - features: DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.93643254]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-04-30 00:00:00
# Test period - features: DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.9658827]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-05-31 00:00:00
# Test period - features: DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.99121505]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-06-30 00:00:00
# Test period - features: DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.89161897]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-07-31 00:00:00
# Test period - features: DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.59475964]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-08-31 00:00:00
# Test period - features: DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.45792106]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-09-30 00:00:00
# Test period - features: DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.17805581]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-10-31 00:00:00
# Test period - features: DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.25689536]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-11-30 00:00:00
# Test period - features: DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.23403469]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-12-31 00:00:00
# Test period - features: DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.32330057]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-01-31 00:00:00
# Test period - features: DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.29085281]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-02-28 00:00:00
# Test period - features: DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.47521272]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-03-31 00:00:00
# Test period - features: DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.42949402]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-04-30 00:00:00
# Test period - features: DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.21732122]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-05-31 00:00:00
# Test period - features: DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.40974528]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-06-30 00:00:00
# Test period - features: DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.5682247]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-07-31 00:00:00
# Test period - features: DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0606446]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-08-31 00:00:00
# Test period - features: DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.196285]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-09-30 00:00:00
# Test period - features: DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4056158]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-10-31 00:00:00
# Test period - features: DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7273973]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-11-30 00:00:00
# Test period - features: DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.242144]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-12-31 00:00:00
# Test period - features: DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.8406048]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-01-31 00:00:00
# Test period - features: DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3236785]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-02-28 00:00:00
# Test period - features: DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.456895]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-03-31 00:00:00
# Test period - features: DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.0495195]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-04-30 00:00:00
# Test period - features: DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.2788804]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-05-31 00:00:00
# Test period - features: DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.4871678]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-06-30 00:00:00
# Test period - features: DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.4467387]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-07-31 00:00:00
# Test period - features: DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.879518]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-08-31 00:00:00
# Test period - features: DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.170762]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-09-30 00:00:00
# Test period - features: DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.3658137]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-10-31 00:00:00
# Test period - features: DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.914147]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-11-30 00:00:00
# Test period - features: DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.714425]
# -------------------------------------------------------
# Horizon: 2
# Training predictor period: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training dependent variable period: 1997-03-31 00:00:00 to 2015-12-31 00:00:00
# Number of finished trials: 1000
# Horizon: 2
# ------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2015-12-31 00:00:00
# Test period - features: DatetimeIndex(['2015-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.682499]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-01-31 00:00:00
# Test period - features: DatetimeIndex(['2015-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7494191]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-02-29 00:00:00
# Test period - features: DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7659037]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-03-31 00:00:00
# Test period - features: DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.49061564]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-02-29 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-04-30 00:00:00
# Test period - features: DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.45011958]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-05-31 00:00:00
# Test period - features: DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.55365354]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-06-30 00:00:00
# Test period - features: DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.28841788]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-07-31 00:00:00
# Test period - features: DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.6296367]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-08-31 00:00:00
# Test period - features: DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.49363533]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-09-30 00:00:00
# Test period - features: DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.51028484]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-10-31 00:00:00
# Test period - features: DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.3996423]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-11-30 00:00:00
# Test period - features: DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.37442434]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-12-31 00:00:00
# Test period - features: DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.534789]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-01-31 00:00:00
# Test period - features: DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.55987996]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-02-28 00:00:00
# Test period - features: DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.7743601]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-03-31 00:00:00
# Test period - features: DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8487151]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-04-30 00:00:00
# Test period - features: DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8762345]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-05-31 00:00:00
# Test period - features: DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.72011185]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-06-30 00:00:00
# Test period - features: DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8434894]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-07-31 00:00:00
# Test period - features: DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8161639]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-08-31 00:00:00
# Test period - features: DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.57338315]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-09-30 00:00:00
# Test period - features: DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.31978816]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-10-31 00:00:00
# Test period - features: DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.63792014]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-11-30 00:00:00
# Test period - features: DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.6322757]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-12-31 00:00:00
# Test period - features: DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.45156574]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-01-31 00:00:00
# Test period - features: DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.56503284]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-02-28 00:00:00
# Test period - features: DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.6056635]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-03-31 00:00:00
# Test period - features: DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.70185286]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-04-30 00:00:00
# ...
# Training period - target : 1997-04-30 00:00:00 to 2019-10-31 00:00:00
# Test period - features: DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8529691]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-11-30 00:00:00
# Test period - features: DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.95307183]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-12-31 00:00:00
# Test period - features: DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.886761]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-01-31 00:00:00
# Test period - features: DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8797]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-02-29 00:00:00
# Test period - features: DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.766536]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-03-31 00:00:00
# Test period - features: DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.8082194]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-04-30 00:00:00
# Test period - features: DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.632215]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-02-29 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-05-31 00:00:00
# Test period - features: DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.75533634]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-06-30 00:00:00
# Test period - features: DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.5343928]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-07-31 00:00:00
# Test period - features: DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.40970904]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-08-31 00:00:00
# Test period - features: DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.5300789]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-09-30 00:00:00
# Test period - features: DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.14829649]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-10-31 00:00:00
# Test period - features: DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.03860053]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-11-30 00:00:00
# Test period - features: DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.18516432]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-12-31 00:00:00
# Test period - features: DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.43208784]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-01-31 00:00:00
# Test period - features: DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [-0.15845564]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-02-28 00:00:00
# Test period - features: DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.11093387]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-03-31 00:00:00
# Test period - features: DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.3385919]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-04-30 00:00:00
# Test period - features: DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.493137]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-02-28 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-05-31 00:00:00
# Test period - features: DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.5886113]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-06-30 00:00:00
# Test period - features: DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.26302814]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-07-31 00:00:00
# Test period - features: DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.90131634]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-08-31 00:00:00
# Test period - features: DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.981791]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-09-30 00:00:00
# Test period - features: DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5018107]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-10-31 00:00:00
# Test period - features: DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.36612]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-11-30 00:00:00
# Test period - features: DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.0682914]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-12-31 00:00:00
# Test period - features: DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.169464]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-01-31 00:00:00
# Test period - features: DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.5977263]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-02-28 00:00:00
# Test period - features: DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.570483]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-03-31 00:00:00
# Test period - features: DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.6919029]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-04-30 00:00:00
# Test period - features: DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.2830746]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-02-28 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-05-31 00:00:00
# Test period - features: DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.4448714]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-06-30 00:00:00
# Test period - features: DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.1906552]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-07-31 00:00:00
# Test period - features: DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.272361]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-08-31 00:00:00
# Test period - features: DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.1510222]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-09-30 00:00:00
# Test period - features: DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.180088]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-10-31 00:00:00
# Test period - features: DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.8102884]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-11-30 00:00:00
# Test period - features: DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [4.361391]
# -------------------------------------------------------

# %%
mine_g.save_forecast(forecast_result_df=neig_cat_prediction.reset_index(drop=True), cat_file_path=save_cat_file_path, category=cat_short)

# %%
yoy_real = pd.read_csv(f"data/preprocessed/{cat_short}_yoy_infl.csv", parse_dates=True, index_col='date')
yoy_real_test = yoy_real[(yoy_real.index > mine_g.train_test_split_date) & (yoy_real.index <= mine_g.max_X_date)]
#df_compare = pd.concat([energy_cat_prediction, yoy_real_test], axis = 1)

print(mean_absolute_error(yoy_real_test,neig_cat_prediction.iloc[:, 0]))
print(np.sqrt(mean_squared_error(yoy_real_test,neig_cat_prediction.iloc[:, 0])))
# Out:
# 0.8589574803267735
# 1.2256968475071839

# %% [markdown]
# # Services:

# %%
cat_short = 'services'
category = 'Services'
hicp_cat_path = f'data/preprocessed/{cat_short}_yoy_infl.csv'
save_cat_file_path = f'data/forecast_results/{cat_short}_forecast.csv'

HICP_monthly, HICP_class, HICP_cat = mine_g.import_data_all(hicp_all_path=hicp_all_path,
                                                     hicp_class_path=hicp_class_path,
                                                     hicp_cat_path=hicp_cat_path)

cat_df = mine_g.split_into_category(category=category,
                             HICP_class=HICP_class,
                             HICP_monthly=HICP_monthly)
services_cat_prediction = pd.DataFrame(index=date_range)
# Out:
# Number of items in Services group:  148
# /Users/lananhnguyen/Desktop/thesis/thesis_code/main/packages/mine_generic.py:198: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df.fillna(0, inplace=True)

# %%
for h in [1, 2, 3]:
    X_cat_train, X_cat_test, y_cat_train, y_cat_test = mine_g.split_train_test_set(X = cat_df, y = HICP_cat, h = h)

    best_param = mine_s.hyperparam_tuning_optuna(mine_s.objective_xgb, X_cat_train, y_cat_train)

    # save best_param:

    with open(f'models/{model}_h_{h}_hyperparam.json', 'w') as json_file:
        json.dump(best_param, json_file)

    N, T = len(X_cat_train), len(X_cat_test)

    y_pred = generate_forecast(X = cat_df, y = HICP_cat, N = N, T = T, h = h, hyperparam=best_param)
    services_cat_prediction.loc[:, f'{model}_{cat_short}_h_{h}'] = y_pred
# Out:
# Horizon: 1
# Training predictor period: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training dependent variable period: 1997-02-28 00:00:00 to 2015-12-31 00:00:00
# Number of finished trials: 1000
# Horizon: 1
# ------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2015-12-31 00:00:00
# Test period - features: DatetimeIndex(['2015-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.024265]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-01-31 00:00:00
# Test period - features: DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6959802]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-02-29 00:00:00
# Test period - features: DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8772748]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-02-29 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-03-31 00:00:00
# Test period - features: DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7850505]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-04-30 00:00:00
# Test period - features: DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2766942]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-05-31 00:00:00
# Test period - features: DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0228208]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-06-30 00:00:00
# Test period - features: DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2820988]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-07-31 00:00:00
# Test period - features: DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.411754]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-08-31 00:00:00
# Test period - features: DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4234298]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-09-30 00:00:00
# Test period - features: DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1443186]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-10-31 00:00:00
# Test period - features: DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3386538]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-11-30 00:00:00
# Test period - features: DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2100736]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2016-12-31 00:00:00
# Test period - features: DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3848354]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-01-31 00:00:00
# Test period - features: DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.549759]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-02-28 00:00:00
# Test period - features: DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5190369]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-03-31 00:00:00
# Test period - features: DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1914867]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-04-30 00:00:00
# Test period - features: DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1638197]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-05-31 00:00:00
# Test period - features: DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2563787]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-06-30 00:00:00
# Test period - features: DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.275805]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-07-31 00:00:00
# Test period - features: DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4023192]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-08-31 00:00:00
# Test period - features: DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7908481]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-09-30 00:00:00
# Test period - features: DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3518667]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-10-31 00:00:00
# Test period - features: DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2401859]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-11-30 00:00:00
# Test period - features: DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2092664]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2017-12-31 00:00:00
# Test period - features: DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2118466]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-01-31 00:00:00
# Test period - features: DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0676154]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-02-28 00:00:00
# Test period - features: DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2146051]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-03-31 00:00:00
# Test period - features: DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4383296]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-04-30 00:00:00
# Test period - features: DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2702396]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-05-31 00:00:00
# Test period - features: DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3746996]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-06-30 00:00:00
# Test period - features: DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.416339]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-07-31 00:00:00
# Test period - features: DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7591573]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-08-31 00:00:00
# Test period - features: DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6850288]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-09-30 00:00:00
# Test period - features: DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7282866]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-10-31 00:00:00
# Test period - features: DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.797435]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-11-30 00:00:00
# Test period - features: DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7610136]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2018-12-31 00:00:00
# Test period - features: DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8420101]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-01-31 00:00:00
# Test period - features: DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7540077]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-02-28 00:00:00
# Test period - features: DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7032145]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-03-31 00:00:00
# Test period - features: DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6009259]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-04-30 00:00:00
# Test period - features: DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.0817676]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-05-31 00:00:00
# Test period - features: DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.480009]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-06-30 00:00:00
# Test period - features: DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3662666]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-07-31 00:00:00
# Test period - features: DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4849178]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-08-31 00:00:00
# Test period - features: DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4215379]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-09-30 00:00:00
# Test period - features: DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3378837]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-10-31 00:00:00
# Test period - features: DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6569093]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-11-30 00:00:00
# Test period - features: DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5646949]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2019-12-31 00:00:00
# Test period - features: DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8874762]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-01-31 00:00:00
# Test period - features: DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5929422]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-02-29 00:00:00
# Test period - features: DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.487065]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-02-29 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-03-31 00:00:00
# Test period - features: DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5007838]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-04-30 00:00:00
# Test period - features: DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3918811]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-05-31 00:00:00
# Test period - features: DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9139699]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-06-30 00:00:00
# Test period - features: DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3850001]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-07-31 00:00:00
# Test period - features: DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7960681]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-08-31 00:00:00
# Test period - features: DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3917518]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-09-30 00:00:00
# Test period - features: DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3280708]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-10-31 00:00:00
# Test period - features: DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2576238]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-11-30 00:00:00
# Test period - features: DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1895804]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2020-12-31 00:00:00
# Test period - features: DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.0809892]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-01-31 00:00:00
# Test period - features: DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9617162]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-02-28 00:00:00
# Test period - features: DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1186173]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-03-31 00:00:00
# Test period - features: DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7887757]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-04-30 00:00:00
# Test period - features: DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2747875]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-05-31 00:00:00
# Test period - features: DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2573538]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-06-30 00:00:00
# Test period - features: DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5603349]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-07-31 00:00:00
# Test period - features: DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6216966]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-08-31 00:00:00
# Test period - features: DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6083567]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-09-30 00:00:00
# Test period - features: DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4945906]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-10-31 00:00:00
# Test period - features: DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.865455]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-11-30 00:00:00
# Test period - features: DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.375639]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-11-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2021-12-31 00:00:00
# Test period - features: DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9934446]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-12-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-01-31 00:00:00
# Test period - features: DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.265884]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-01-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-02-28 00:00:00
# Test period - features: DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3813808]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-02-28 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-03-31 00:00:00
# Test period - features: DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.4479427]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-03-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-04-30 00:00:00
# Test period - features: DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.6550395]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-04-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-05-31 00:00:00
# Test period - features: DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.6919127]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-05-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-06-30 00:00:00
# Test period - features: DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.7087488]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-06-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-07-31 00:00:00
# Test period - features: DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.558147]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-07-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-08-31 00:00:00
# Test period - features: DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9628829]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-08-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-09-30 00:00:00
# Test period - features: DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.0764654]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-09-30 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-10-31 00:00:00
# Test period - features: DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.8917537]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-10-31 00:00:00
# Training period - target : 1997-02-28 00:00:00 to 2022-11-30 00:00:00
# Test period - features: DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [3.079292]
# -------------------------------------------------------
# Horizon: 2
# Training predictor period: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training dependent variable period: 1997-03-31 00:00:00 to 2015-12-31 00:00:00
# Number of finished trials: 1000
# Horizon: 2
# ------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2015-12-31 00:00:00
# Test period - features: DatetimeIndex(['2015-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8437526]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-01-31 00:00:00
# Test period - features: DatetimeIndex(['2015-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1361048]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-02-29 00:00:00
# Test period - features: DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5024459]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-03-31 00:00:00
# Test period - features: DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6394588]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-02-29 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-04-30 00:00:00
# Test period - features: DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.1934061]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-05-31 00:00:00
# Test period - features: DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3037261]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-06-30 00:00:00
# Test period - features: DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3855274]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-07-31 00:00:00
# Test period - features: DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4213072]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-08-31 00:00:00
# Test period - features: DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.29209]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-09-30 00:00:00
# Test period - features: DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3398738]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-10-31 00:00:00
# Test period - features: DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3030412]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-11-30 00:00:00
# Test period - features: DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4492491]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-12-31 00:00:00
# Test period - features: DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3593036]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-01-31 00:00:00
# Test period - features: DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1731088]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-02-28 00:00:00
# Test period - features: DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8744297]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-03-31 00:00:00
# Test period - features: DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6299906]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-04-30 00:00:00
# Test period - features: DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5253532]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-05-31 00:00:00
# Test period - features: DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2075212]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-06-30 00:00:00
# Test period - features: DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3446159]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-07-31 00:00:00
# Test period - features: DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3215003]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-08-31 00:00:00
# Test period - features: DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7018248]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-09-30 00:00:00
# Test period - features: DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2820679]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-10-31 00:00:00
# Test period - features: DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3486792]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-11-30 00:00:00
# Test period - features: DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5352445]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-12-31 00:00:00
# Test period - features: DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3511568]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-01-31 00:00:00
# Test period - features: DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2798163]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-02-28 00:00:00
# Test period - features: DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2813005]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-03-31 00:00:00
# Test period - features: DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.459254]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-04-30 00:00:00
# Test period - features: DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# ...
# Training period - target : 1997-04-30 00:00:00 to 2019-10-31 00:00:00
# Test period - features: DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3404939]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-11-30 00:00:00
# Test period - features: DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9195782]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2019-12-31 00:00:00
# Test period - features: DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5822861]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-01-31 00:00:00
# Test period - features: DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4732281]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-02-29 00:00:00
# Test period - features: DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.665797]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-03-31 00:00:00
# Test period - features: DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8317566]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-04-30 00:00:00
# Test period - features: DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3061819]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-02-29 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-05-31 00:00:00
# Test period - features: DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4415073]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-06-30 00:00:00
# Test period - features: DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4167413]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-07-31 00:00:00
# Test period - features: DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.4046316]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-08-31 00:00:00
# Test period - features: DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5980656]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-09-30 00:00:00
# Test period - features: DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3430728]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-10-31 00:00:00
# Test period - features: DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3288562]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-11-30 00:00:00
# Test period - features: DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2847656]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2020-12-31 00:00:00
# Test period - features: DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [0.9233196]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-01-31 00:00:00
# Test period - features: DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2281036]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-02-28 00:00:00
# Test period - features: DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7674745]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-03-31 00:00:00
# Test period - features: DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8735706]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-04-30 00:00:00
# Test period - features: DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.7708141]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-02-28 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-05-31 00:00:00
# Test period - features: DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.6878334]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-06-30 00:00:00
# Test period - features: DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5452557]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-07-31 00:00:00
# Test period - features: DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.3128103]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-08-31 00:00:00
# Test period - features: DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.2604598]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-09-30 00:00:00
# Test period - features: DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.5516486]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-10-31 00:00:00
# Test period - features: DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.0316186]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-11-30 00:00:00
# Test period - features: DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.423723]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-09-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2021-12-31 00:00:00
# Test period - features: DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1548808]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-10-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-01-31 00:00:00
# Test period - features: DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.790807]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-11-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-02-28 00:00:00
# Test period - features: DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.8686864]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-12-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-03-31 00:00:00
# Test period - features: DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.710214]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-01-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-04-30 00:00:00
# Test period - features: DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.5917737]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-02-28 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-05-31 00:00:00
# Test period - features: DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.4046261]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-03-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-06-30 00:00:00
# Test period - features: DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.4113276]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-04-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-07-31 00:00:00
# Test period - features: DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.206153]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-05-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-08-31 00:00:00
# Test period - features: DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [1.9668506]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-06-30 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-09-30 00:00:00
# Test period - features: DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.1499357]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-07-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-10-31 00:00:00
# Test period - features: DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.3342943]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-08-31 00:00:00
# Training period - target : 1997-04-30 00:00:00 to 2022-11-30 00:00:00
# Test period - features: DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast: [2.8136845]
# -------------------------------------------------------

# %%
yoy_real = pd.read_csv(f"data/preprocessed/{cat_short}_yoy_infl.csv", parse_dates=True, index_col='date')
yoy_real_test = yoy_real[(yoy_real.index > mine_g.train_test_split_date) & (yoy_real.index <= mine_g.max_X_date)]
#df_compare = pd.concat([energy_cat_prediction, yoy_real_test], axis = 1)

print(mean_absolute_error(yoy_real_test,services_cat_prediction.iloc[:, 0]))
print(np.sqrt(mean_squared_error(yoy_real_test,services_cat_prediction.iloc[:, 0])))
# Out:
# 0.538195305865574
# 0.6867911129159167

# %%
mine_g.save_forecast(forecast_result_df=services_cat_prediction.reset_index(drop=True), cat_file_path=save_cat_file_path, category=cat_short)

# %%
from os import chdir
chdir('/Users/lananhnguyen/Desktop/thesis/thesis_code')
from main.packages.mine_generic import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
import xgboost as xgb
import optuna
from sklearn.pipeline import make_pipeline

# %%
cat = 'food'
hicp_all_path = 'data/preprocessed/hicp_yoy.csv'
hicp_class_path = 'data/HICP_COICOP10s.xlsx'
hicp_cat_path = f'data/preprocessed/{cat}_yoy_infl.csv'
category = 'Food'

HICP_monthly, HICP_class, HICP_cat = import_data_all(hicp_all_path=hicp_all_path,
                                                     hicp_class_path=hicp_class_path,
                                                     hicp_cat_path=hicp_cat_path)

cat_df = split_into_category(category=category,
                             HICP_class=HICP_class,
                             HICP_monthly=HICP_monthly)
# Out:
# Number of items in Food group:  180
# Horizon: 2
# Training predictor period: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training dependent variable period: 1997-03-31 00:00:00 to 2015-12-31 00:00:00
# /Users/lananhnguyen/Desktop/thesis/thesis_code/main/packages/load.py:260: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_df.fillna(0, inplace=True)

# %%
h = 2
X_cat_train, y_cat_train = split_train_set(X_df=cat_df,
                                           y=HICP_cat,
                                           h = h)

# %% [markdown]
# # Hyperparameter tuning:
#
# belong to each specific model

# %%
import datetime
#from optuna_dashboard import run_server

#storage = optuna.storages.InMemoryStorage()

# 1. Define an objective function to be maximized.

def objective(trial, X_cat_train, y_cat_train, k_fold = 5):
    """
    For XBG hyperparam tuning
    """
    params = {
        "verbosity": 0,
        'objective': 'reg:squarederror',
        'booster': 'gbtree',
        'eval_metric': 'mae',
        'tree_method': 'hist',
        'n_jobs': -1,
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'num_boosted_rounds': 100000,
        'early_stopping_rounds': 100,

        'gamma': trial.suggest_float('gamma', 0.0, 10),
        'min_child_weight': trial.suggest_float('min_child_weight', 0.01, 10.0),

        'lambda': trial.suggest_float('lambda', 0.01, 1),
        'alpha': trial.suggest_float('alpha', 0.01, 0.5),

        # sampling ratio for training data.
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
    }
    tscv = TimeSeriesSplit(n_splits=k_fold, test_size=24)

    ## Do it explicitly via xgb API:
    cv_mae = [None]*k_fold

    # Add pruning:
    pruning_callback = optuna.integration.XGBoostPruningCallback(trial, "validation-mae")
        
    for i, (train_index, test_index) in enumerate(tscv.split(X_cat_train, y_cat_train)):
        # split data:
        X_train, X_test = X_cat_train.iloc[train_index], X_cat_train.iloc[test_index]
        y_train, y_test = y_cat_train.iloc[train_index], y_cat_train.iloc[test_index]
        
        # standard scaler:
        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        # Transform data into xgboost type:
        dtrain = xgb.DMatrix(X_train, label=y_train)
        dvalid = xgb.DMatrix(X_test, label=y_test)

        # Train model:
        model = xgb.train(params, dtrain, evals=[(dvalid, "validation")], callbacks=[pruning_callback], verbose_eval=False)
        
        y_test_pred = model.predict(dvalid)
        cv_mae[i] = mean_absolute_error(y_test, y_test_pred)
        # saving the individual fold holdout metrics 
        # uncomment this line if you don't want this
        #trial.set_user_attr('split_mae', cv_mae)

    # return the mean of all 5 folds        
    return np.mean(cv_mae)

    ## Do it implicitly via scikit-learn
    # Create a pipeline for preprocessing before XGB:
        
    #model = XGBRegressor(**params) #, callbacks=[pruning_callback]
    #pipeline_ = make_pipeline(StandardScaler(), model)

    # Use cross_val_score to get the mean MAE over multiple splits:
    # here it'll split data as tscv, 
    # then for each fold: it'll scale training data, fit model, then scale validation set, get prediction and put out MAE
    #scores = -cross_val_score(pipeline_, X_cat_train, y_cat_train, cv=tscv, scoring='neg_mean_absolute_error', n_jobs=-1, verbose=0)
    #print(scores)
    #return scores.mean()

# 2. Create a study object and optimize the objective function.
pruner = optuna.pruners.MedianPruner(n_warmup_steps=5)

sampler = optuna.samplers.TPESampler(seed=1234)

study = optuna.create_study(
    pruner=pruner, 
    direction='minimize',
    sampler=sampler
    #storage=storage
)
study.optimize(objective, n_trials=1000)
#run_server(storage, host="localhost", port=8080)
print("Number of finished trials: {}".format(len(study.trials)))


# Get results:
results = study.trials_dataframe(attrs=('number','value','duration', 'params'))
results = results.rename(columns={'value':'mae'})
results['duration'] = results['duration']/np.timedelta64(1, 's')
results = results.sort_values(by='mae',ascending=True).iloc[:100, :]
results.to_csv(f'model/mae_xgboost_h_{h}.csv',index=False)

best_params = study.best_params
best_trial = study.best_trial
# Out:
# [I 2024-04-05 18:42:59,741] A new study created in memory with name: no-name-43672afc-542e-4081-b013-9327cbec009a
# [I 2024-04-05 18:43:00,002] Trial 0 finished with value: 1.2608137257746628 and parameters: {'learning_rate': 0.06554064060987876, 'max_depth': 14, 'num_boosted_rounds': 49, 'lambda': 0.7875049978766315, 'alpha': 0.3921881459782137, 'subsample': 0.6362963026413209, 'colsample_bytree': 0.6382321275715483}. Best is trial 0 with value: 1.2608137257746628.
# [I 2024-04-05 18:43:00,430] Trial 1 finished with value: 0.9642321374914369 and parameters: {'learning_rate': 0.24254293148515557, 'max_depth': 20, 'num_boosted_rounds': 89, 'lambda': 0.364239097258288, 'alpha': 0.25548761150649474, 'subsample': 0.8417314675860681, 'colsample_bytree': 0.85635101349145}. Best is trial 1 with value: 0.9642321374914369.
# [I 2024-04-05 18:43:00,796] Trial 2 finished with value: 1.0264000341682082 and parameters: {'learning_rate': 0.11737271888921452, 'max_depth': 13, 'num_boosted_rounds': 55, 'lambda': 0.023630765094775418, 'alpha': 0.38868504459006326, 'subsample': 0.9413205953180583, 'colsample_bytree': 0.6824429919506861}. Best is trial 1 with value: 0.9642321374914369.
# [I 2024-04-05 18:43:01,080] Trial 3 finished with value: 0.9514874802444494 and parameters: {'learning_rate': 0.18846489174571315, 'max_depth': 4, 'num_boosted_rounds': 43, 'lambda': 0.9338087009626964, 'alpha': 0.32917529018102293, 'subsample': 0.698601288863077, 'colsample_bytree': 0.8943650714703728}. Best is trial 3 with value: 0.9514874802444494.
# [I 2024-04-05 18:43:01,387] Trial 4 finished with value: 1.0475489835902807 and parameters: {'learning_rate': 0.10188247542897265, 'max_depth': 13, 'num_boosted_rounds': 89, 'lambda': 0.4418116896567226, 'alpha': 0.40305234461927797, 'subsample': 0.5718834122572822, 'colsample_bytree': 0.8521304855591677}. Best is trial 3 with value: 0.9514874802444494.
# [I 2024-04-05 18:43:01,634] Trial 5 finished with value: 1.081324841079554 and parameters: {'learning_rate': 0.214328579374976, 'max_depth': 6, 'num_boosted_rounds': 94, 'lambda': 0.44771934785013484, 'alpha': 0.45556481989651154, 'subsample': 0.529904611389926, 'colsample_bytree': 0.5921435419069068}. Best is trial 3 with value: 0.9514874802444494.
# [I 2024-04-05 18:43:01,673] Trial 6 pruned. Trial was pruned at iteration 5.
# [I 2024-04-05 18:43:01,712] Trial 7 pruned. Trial was pruned at iteration 6.
# [I 2024-04-05 18:43:01,756] Trial 8 pruned. Trial was pruned at iteration 6.
# [I 2024-04-05 18:43:01,794] Trial 9 pruned. Trial was pruned at iteration 5.
# [I 2024-04-05 18:43
. Best is trial 571 with value: 0.8324293579328648.
# [I 2024-04-05 18:45:54,129] Trial 993 finished with value: 0.9815003223893088 and parameters: {'learning_rate': 0.28277443608490904, 'max_depth': 9, 'num_boosted_rounds': 59, 'lambda': 0.22465431632536126, 'alpha': 0.23376192065430607, 'subsample': 0.7596871320483027, 'colsample_bytree': 0.850474516263484}. Best is trial 571 with value: 0.8324293579328648.
# [I 2024-04-05 18:45:54,575] Trial 994 finished with value: 0.8596305401473409 and parameters: {'learning_rate': 0.27208420640167374, 'max_depth': 10, 'num_boosted_rounds': 61, 'lambda': 0.2002182784277765, 'alpha': 0.2488054962178594, 'subsample': 0.7435884209617807, 'colsample_bytree': 0.8467114372486603}. Best is trial 571 with value: 0.8324293579328648.
# [I 2024-04-05 18:45:55,016] Trial 995 finished with value: 0.9036519113938464 and parameters: {'learning_rate': 0.27430328872993015, 'max_depth': 10, 'num_boosted_rounds': 61, 'lambda': 0.19634139481420324, 'alpha': 0.24930986906519914, 'subsample': 0.7479308160419036, 'colsample_bytree': 0.8589867634312185}. Best is trial 571 with value: 0.8324293579328648.
# [I 2024-04-05 18:45:55,448] Trial 996 finished with value: 1.0566330371612762 and parameters: {'learning_rate': 0.27201346270285864, 'max_depth': 9, 'num_boosted_rounds': 62, 'lambda': 0.1935324062912018, 'alpha': 0.24731829082148307, 'subsample': 0.7279554717968634, 'colsample_bytree': 0.8625179150807178}. Best is trial 571 with value: 0.8324293579328648.
# [I 2024-04-05 18:45:55,884] Trial 997 finished with value: 0.9118586843567886 and parameters: {'learning_rate': 0.27193625226187323, 'max_depth': 10, 'num_boosted_rounds': 61, 'lambda': 0.1964180377515013, 'alpha': 0.24997193847386714, 'subsample': 0.7390984867031589, 'colsample_bytree': 0.8668344086876534}. Best is trial 571 with value: 0.8324293579328648.
# [I 2024-04-05 18:45:56,004] Trial 998 pruned. Trial was pruned at iteration 5.
# [I 2024-04-05 18:45:56,117] Trial 999 pruned. Trial was pruned at iteration 5.
# Number of finished trials: 1000

# %%
import joblib
joblib.dump(study, 'models/xgboost_trial.pkl')
# Out:
# ['models/xgboost_trial.pkl']

# %%
# get results
results = study.trials_dataframe(attrs=('number','value','duration', 'params'))
results = results.rename(columns={'value':'mae'})
results['duration'] = results['duration']/np.timedelta64(1, 's')
results = results.sort_values(by='mae',ascending=True)
results.to_csv(f'mae_xgboost_h_{h}.csv',index=False)
results.head(10)
# Out:
#      number       mae  duration  params_alpha  params_colsample_bytree  \
# 874     874  0.471055  0.141757      0.193797                 0.811638
# 785     785  0.473332  0.113961      0.249292                 0.840924
# 796     796  0.474013  0.101845      0.283566                 0.842758
# 823     823  0.474103  0.106120      0.215805                 0.788363
# 531     531  0.474307  0.083769      0.266723                 0.742482
# 938     938  0.474723  0.117450      0.208316                 0.828744
# 699     699  0.475213  0.100660      0.250043                 0.875186
# 952     952  0.476170  0.108756      0.234223                 0.844717
# 509     509  0.476577  0.086255      0.271099                 0.755896
# 943     943  0.477465  0.119930      0.218378                 0.791196
#
#      params_lambda  params_learning_rate  params_max_depth  \
# 874       0.193251              0.269102                 9
# 785       0.544477              0.228318                13
# 796       0.659251              0.246838                 7
# 823       0.293164              0.275430                 9
# 531       0.510359              0.231371                13
# 938       0.187908              0.271499                 8
# 699       0.175252              0.274779                12
# 952       0.288706              0.276999                 9
# 509       0.135441              0.276053                12
# 943       0.247882              0.260062                10
#
#      params_num_boosted_rounds  params_subsample
# 874                         53          0.713331
# 785                         97          0.750251
# 796                         91          0.764307
# 823                         47          0.714899
# 531                         10          0.692318
# 938                         55          0.726878
# 699                         98          0.748898
# 952                         61          0.743631
# 509                         98          0.706170
# 943                         55          0.738464

# %% [markdown]
# # Predict and save:

# %%
best_params = {'learning_rate': 0.2907681843683012,
 'max_depth': 7,
 #'num_boosted_rounds': 100,
 'lambda': 0.5916745313772411,
 'alpha': 0.011239143280416843,
 'subsample': 0.7313441579055963,
 'colsample_bytree': 0.8529057716885262}

# %%
def train_test_split(X, y, h, split_date): 
    """
    Split the train and test set for forecasting

    """
    print(f'Horizon: {h}')
    print('------------------------')

    X_train = X[X.index <= split_date].iloc[:-h, :]
    X_test = X[~X.index.isin(X_train.index)]

    #y_train = y[y.index <= split_date][h:]
    y_test = y[y.index > split_date]
    N, T = len(X_train), len(X_test)
    
    return N, T, y_test

N, T, y_test = train_test_split(X = cat_df, y = HICP_cat, h = 2, split_date= train_test_split_date)
# Out:
# Horizon: 2
# Training predictor period: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training dependent variable period: 1997-03-31 00:00:00 to 2015-12-31 00:00:00
# Test predictor period: 2015-11-30 00:00:00 to 2022-12-31 00:00:00
# Test dependent variable period: 2016-01-31 00:00:00 to 2023-07-31 00:00:00
# --------------------------------------------

# %%
def generate_forecast(X, y, N, T, h, hyperparam, model):
    y_pred_series = []
    for i in range(2, T+2-h): #T+1-h
        X_train = X.iloc[:N+i-h, :]
        y_train = y.iloc[h:N+i, :]

        X_test = X.iloc[N-h+i:N-h+i+1, :] #:N+i+3
        y_test = y.iloc[N+i:N+i+1, :] #:N+i+3+h

        print(f'Training period - features: {X_train.index[0]} to {X_train.index[-1]}')
        print(f'Training period - target : {y_train.index[0]} to {y_train.index[-1]}')
        print(f'Test period - features: {X_test.index}')
        print(f'Test period - target : {y_test.index}')

        # Standard scale:
        # For all things

        #### More specific to its own model
        y_test_pred = model(X_train, X_test, y_train, y_test, hyperparam)

        print(f'Forecast: {y_test_pred}')
        print('-------------------------------------------------------')
        y_pred_series.extend(y_test_pred.tolist())
        if X_test.index[-1] == X.index[-1]:
            break
    return y_pred_series
    
y_pred_series_h_2 = generate_forecast(X = cat_df, y = HICP_cat, N = N, T = T, h = h, hyperparam=best_params)
# Out:
# Horizon: 2
# ------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2015-12-31 00:00:00
# Test period - features: DatetimeIndex(['2015-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [0.8332401]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-01-31 00:00:00
# Test period - features: DatetimeIndex(['2015-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.33021]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2015-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-02-29 00:00:00
# Test period - features: DatetimeIndex(['2016-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.111415]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-03-31 00:00:00
# Test period - features: DatetimeIndex(['2016-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.261235]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-02-29 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-04-30 00:00:00
# Test period - features: DatetimeIndex(['2016-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.0379484]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-05-31 00:00:00
# Test period - features: DatetimeIndex(['2016-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.1206397]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-06-30 00:00:00
# Test period - features: DatetimeIndex(['2016-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.0700941]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-07-31 00:00:00
# Test period - features: DatetimeIndex(['2016-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.6861725]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-08-31 00:00:00
# Test period - features: DatetimeIndex(['2016-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [0.4978697]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-09-30 00:00:00
# Test period - features: DatetimeIndex(['2016-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.5666136]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-10-31 00:00:00
# Test period - features: DatetimeIndex(['2016-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.1489607]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-11-30 00:00:00
# Test period - features: DatetimeIndex(['2016-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.3357668]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2016-12-31 00:00:00
# Test period - features: DatetimeIndex(['2016-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.7573051]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-01-31 00:00:00
# Test period - features: DatetimeIndex(['2016-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.7479963]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2016-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-02-28 00:00:00
# Test period - features: DatetimeIndex(['2017-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.5335736]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-03-31 00:00:00
# Test period - features: DatetimeIndex(['2017-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.611736]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-04-30 00:00:00
# Test period - features: DatetimeIndex(['2017-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.0139754]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-05-31 00:00:00
# Test period - features: DatetimeIndex(['2017-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.364918]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-06-30 00:00:00
# Test period - features: DatetimeIndex(['2017-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.1466308]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-07-31 00:00:00
# Test period - features: DatetimeIndex(['2017-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.2707434]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-08-31 00:00:00
# Test period - features: DatetimeIndex(['2017-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.578476]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-09-30 00:00:00
# Test period - features: DatetimeIndex(['2017-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.475342]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-10-31 00:00:00
# Test period - features: DatetimeIndex(['2017-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.6226242]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-11-30 00:00:00
# Test period - features: DatetimeIndex(['2017-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.7448246]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2017-12-31 00:00:00
# Test period - features: DatetimeIndex(['2017-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.4319093]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-01-31 00:00:00
# Test period - features: DatetimeIndex(['2017-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.056658]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2017-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-02-28 00:00:00
# Test period - features: DatetimeIndex(['2018-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.0682974]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-03-31 00:00:00
# Test period - features: DatetimeIndex(['2018-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.2340214]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-04-30 00:00:00
# Test period - features: DatetimeIndex(['2018-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.7421205]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-05-31 00:00:00
# Test period - features: DatetimeIndex(['2018-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.5358589]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-06-30 00:00:00
# Test period - features: DatetimeIndex(['2018-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.4106345]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-07-31 00:00:00
# Test period - features: DatetimeIndex(['2018-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.8263361]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-08-31 00:00:00
# Test period - features: DatetimeIndex(['2018-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.4639986]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-09-30 00:00:00
# Test period - features: DatetimeIndex(['2018-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.5707219]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-10-31 00:00:00
# Test period - features: DatetimeIndex(['2018-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.5028007]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-11-30 00:00:00
# Test period - features: DatetimeIndex(['2018-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.3229656]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2018-12-31 00:00:00
# Test period - features: DatetimeIndex(['2018-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.1079258]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-01-31 00:00:00
# Test period - features: DatetimeIndex(['2018-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [0.8484488]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2018-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-02-28 00:00:00
# Test period - features: DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.1662235]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-03-31 00:00:00
# Test period - features: DatetimeIndex(['2019-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.4022702]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-04-30 00:00:00
# Test period - features: DatetimeIndex(['2019-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [0.8600307]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-05-31 00:00:00
# Test period - features: DatetimeIndex(['2019-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.2029238]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-06-30 00:00:00
# Test period - features: DatetimeIndex(['2019-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.312655]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-07-31 00:00:00
# Test period - features: DatetimeIndex(['2019-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.4124602]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-08-31 00:00:00
# Test period - features: DatetimeIndex(['2019-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.7412486]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-09-30 00:00:00
# Test period - features: DatetimeIndex(['2019-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.7671195]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-10-31 00:00:00
# Test period - features: DatetimeIndex(['2019-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.1424857]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-11-30 00:00:00
# Test period - features: DatetimeIndex(['2019-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.3228147]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2019-12-31 00:00:00
# Test period - features: DatetimeIndex(['2019-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.7853502]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-01-31 00:00:00
# Test period - features: DatetimeIndex(['2019-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.7526537]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2019-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-02-29 00:00:00
# Test period - features: DatetimeIndex(['2020-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.664708]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-03-31 00:00:00
# Test period - features: DatetimeIndex(['2020-02-29'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.8666713]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-02-29 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-04-30 00:00:00
# Test period - features: DatetimeIndex(['2020-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.986984]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-05-31 00:00:00
# Test period - features: DatetimeIndex(['2020-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [3.3680239]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-06-30 00:00:00
# Test period - features: DatetimeIndex(['2020-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.9210079]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-07-31 00:00:00
# Test period - features: DatetimeIndex(['2020-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.785778]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-08-31 00:00:00
# Test period - features: DatetimeIndex(['2020-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.6030853]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-09-30 00:00:00
# Test period - features: DatetimeIndex(['2020-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.4125981]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-10-31 00:00:00
# Test period - features: DatetimeIndex(['2020-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.3261741]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-11-30 00:00:00
# Test period - features: DatetimeIndex(['2020-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.7862834]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2020-12-31 00:00:00
# Test period - features: DatetimeIndex(['2020-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.1287097]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-01-31 00:00:00
# Test period - features: DatetimeIndex(['2020-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.4310578]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2020-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-02-28 00:00:00
# Test period - features: DatetimeIndex(['2021-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.8750368]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-03-31 00:00:00
# Test period - features: DatetimeIndex(['2021-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.4226313]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-04-30 00:00:00
# Test period - features: DatetimeIndex(['2021-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.094181]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-05-31 00:00:00
# Test period - features: DatetimeIndex(['2021-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.3811246]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-06-30 00:00:00
# Test period - features: DatetimeIndex(['2021-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.3019959]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-07-31 00:00:00
# Test period - features: DatetimeIndex(['2021-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [1.7557482]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-08-31 00:00:00
# Test period - features: DatetimeIndex(['2021-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [2.9144006]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-09-30 00:00:00
# Test period - features: DatetimeIndex(['2021-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [3.58158]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-10-31 00:00:00
# Test period - features: DatetimeIndex(['2021-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [3.9034812]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-11-30 00:00:00
# Test period - features: DatetimeIndex(['2021-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [3.1435292]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-10-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2021-12-31 00:00:00
# Test period - features: DatetimeIndex(['2021-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [3.49898]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-11-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-01-31 00:00:00
# Test period - features: DatetimeIndex(['2021-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [3.9892282]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2021-12-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-02-28 00:00:00
# Test period - features: DatetimeIndex(['2022-01-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [3.8551824]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-01-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-03-31 00:00:00
# Test period - features: DatetimeIndex(['2022-02-28'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [4.19961]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-02-28 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-04-30 00:00:00
# Test period - features: DatetimeIndex(['2022-03-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [4.3452415]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-03-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-05-31 00:00:00
# Test period - features: DatetimeIndex(['2022-04-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [5.5408993]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-04-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-06-30 00:00:00
# Test period - features: DatetimeIndex(['2022-05-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [7.1890635]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-05-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-07-31 00:00:00
# Test period - features: DatetimeIndex(['2022-06-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [9.246118]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-06-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-08-31 00:00:00
# Test period - features: DatetimeIndex(['2022-07-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [10.452305]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-07-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-09-30 00:00:00
# Test period - features: DatetimeIndex(['2022-08-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [11.312986]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-08-31 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-10-31 00:00:00
# Test period - features: DatetimeIndex(['2022-09-30'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-11-30'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [13.300233]
# -------------------------------------------------------
# Training period - features: 1997-01-31 00:00:00 to 2022-09-30 00:00:00
# Training period - target : 1997-03-31 00:00:00 to 2022-11-30 00:00:00
# Test period - features: DatetimeIndex(['2022-10-31'], dtype='datetime64[ns]', name='date', freq=None)
# Test period - target : DatetimeIndex(['2022-12-31'], dtype='datetime64[ns]', name='date', freq=None)
# Forecast:
# [14.366375]
# -------------------------------------------------------

# %%
# Create and save:

forecast_df = pd.DataFrame(columns=[f'xgb_h_{i}' for i in [1, 2, 3]], index = y_test[y_test.index < '2023-01-31'].index)
forecast_df.iloc[:, 1] = y_pred_series_h_2

save_forecast(forecast_df, cat_file_path=f'data/forecast_results/{cat}_forecast.csv')
